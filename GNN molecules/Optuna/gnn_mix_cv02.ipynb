# %%
### grid serch 
# 1. 跑CV 不加seed 跑10次5-fold cross validation
# 2. 跑16* 4 200*4 不加dropout weightdecay 一次加一次不加都跑下 lr不变
# 3. batch_size 16 64 都跑一次
#

# %%
import os 
import pickle
import pandas as pd
import numpy as np

import networkx as nx

import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import Dataset, DataLoader, random_split
from torch_geometric.data import Data, DataLoader as PyGDataLoader
from torch_geometric.utils import from_networkx
from torch_geometric.nn import GINEConv, global_mean_pool, BatchNorm
from torch_geometric.nn.conv.gcn_conv import gcn_norm

from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import KFold

import warnings
warnings.filterwarnings('ignore')

# =============================================================================
#                             DATASET & PREP
# =============================================================================

class MolDataset(Dataset):
    """
    A custom dataset that:
      - Reads external factors from CSV
      - Loads the corresponding pickle for the molecule's graph
      - Converts it into a PyG Data object
    """
    def __init__(self,
                 raw_dataframe: pd.DataFrame,
                 nx_graph_dict: dict,
                 *,
                 component_col: str,
                 global_state_cols: list,
                 label_col: str,
                 transform=None):
        """
        Args:
            raw_dataframe: The input dataframe containing molecule info.
            nx_graph_dict: Dictionary mapping component names to networkx graphs.
            component_col: Column name for the component.
            global_state_cols: List of columns representing external factors.
            label_col: Column name for the regression target.
            transform: Any transform to apply to each PyG Data object.
        """
        self.raw_dataframe = raw_dataframe
        self.nx_graph_dict = nx_graph_dict
        self.component_col = [component_col] if type(component_col) is str else component_col
        self.global_state_cols = global_state_cols
        self.label_col = [label_col] if type(label_col) is str else label_col
        self.transform = transform
        
        required_cols = set(self.global_state_cols + self.label_col + self.component_col)
        for col in required_cols:
            if col not in self.raw_dataframe.columns:
                raise ValueError(f"Missing column in DataFrame: '{col}'")

    def __len__(self):
        return len(self.raw_dataframe)

    def __getitem__(self, idx):
        row = self.raw_dataframe.iloc[idx]
        
        # 1. Load the molecule graph
        component_name = row[self.component_col[0]]  # e.g. "C23"
        pyg_data = self.nx_graph_dict[component_name]

        # 2. Prepare the external factors
        externals = torch.tensor(row[self.global_state_cols].values.astype(float), dtype=torch.float)
        externals = externals.unsqueeze(0)

        # 3. Prepare the label (regression target)
        label = torch.tensor([row[self.label_col][0]], dtype=torch.float)

        # 4. Attach externals & label to the Data object
        pyg_data.externals = externals  # shape [1, external_in_dim]
        pyg_data.y = label  # shape [1]

        if self.transform:
            pyg_data = self.transform(pyg_data)

        return pyg_data


def networkx_to_pyg(nx_graph):
    """
    Convert a networkx graph to a torch_geometric.data.Data object.
    This is a basic template; adjust for your actual node/edge features.
    """
    # Sort nodes to ensure consistent ordering
    node_mapping = {node: i for i, node in enumerate(nx_graph.nodes())}

    x_list = []
    edge_index_list = []
    edge_attr_list = []

    # Node features
    for node in nx_graph.nodes(data=True):
        original_id = node[0]
        attrs = node[1]
        symbol = attrs.get("symbol", "C")
        symbol_id = 0 if symbol == "C" else 1 if symbol == "H" else 2
        x_list.append([symbol_id])

    # Edge features
    for u, v, edge_attrs in nx_graph.edges(data=True):
        u_idx = node_mapping[u]
        v_idx = node_mapping[v]
        edge_index_list.append((u_idx, v_idx))
        bde_pred = edge_attrs.get("bde_pred", 0.0) or 0.0
        bdfe_pred = edge_attrs.get("bdfe_pred", 0.0) or 0.0
        edge_attr_list.append([bde_pred, bdfe_pred])

    x = torch.tensor(x_list, dtype=torch.float)
    edge_index = torch.tensor(edge_index_list, dtype=torch.long).t().contiguous()
    edge_attr = torch.tensor(edge_attr_list, dtype=torch.float)

    data = Data(x=x, edge_index=edge_index, edge_attr=edge_attr)
    return data

# =============================================================================
#                     BASE GNN MODEL (WITH DIM MATCH)
# =============================================================================

class GINE_Regression(nn.Module):
    """
    A GNN for regression using GINEConv layers + edge attributes,
    where all layers have the same hidden_dim (no dimension mismatch).
    """
    def __init__(self,
                 node_in_dim: int,
                 edge_in_dim: int,
                 external_in_dim: int,
                 hidden_dim: int = 128,
                 num_layers: int = 3,
                 dropout: float = 0.1):
        super().__init__()
        
        # Encode edges from edge_in_dim to hidden_dim
        self.edge_encoder = nn.Sequential(
            nn.Linear(edge_in_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim)
        )
        
        # Encode nodes from node_in_dim to hidden_dim
        self.node_encoder = nn.Linear(node_in_dim, hidden_dim)
        
        # Multiple GINEConv layers & corresponding BatchNorm
        self.convs = nn.ModuleList()
        self.bns = nn.ModuleList()
        
        for _ in range(num_layers):
            net = nn.Sequential(
                nn.Linear(hidden_dim, hidden_dim),
                nn.ReLU(),
                nn.Linear(hidden_dim, hidden_dim)
            )
            conv = GINEConv(nn=net)
            self.convs.append(conv)
            self.bns.append(BatchNorm(hidden_dim))

        self.dropout = nn.Dropout(p=dropout)

        # Process external factors
        self.externals_mlp = nn.Sequential(
            nn.Linear(external_in_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(p=dropout),
            nn.Linear(hidden_dim, hidden_dim)
        )

        # Final regression
        self.final_regressor = nn.Sequential(
            nn.Linear(hidden_dim + hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(p=dropout),
            nn.Linear(hidden_dim, 1)
        )

    def forward(self, data):
        x, edge_index, edge_attr, batch = data.x, data.edge_index, data.edge_attr, data.batch

        # Encode
        x = self.node_encoder(x)
        edge_emb = self.edge_encoder(edge_attr)
        
        # Pass through GINEConv layers
        for conv, bn in zip(self.convs, self.bns):
            x = conv(x, edge_index, edge_emb)
            x = bn(x)
            x = F.relu(x)
            x = self.dropout(x)

        # Global pooling
        graph_emb = global_mean_pool(x, batch)

        # Process external factors
        ext_emb = self.externals_mlp(data.externals)

        # Combine & regress
        combined = torch.cat([graph_emb, ext_emb], dim=-1)
        out = self.final_regressor(combined).squeeze(-1)
        return out

# =============================================================================
#                   TRAIN/VALID/EVALUATION UTILS
# =============================================================================

def train_one_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0.0
    count = 0
    for batch_data in loader:
        batch_data = batch_data.to(device)
        optimizer.zero_grad()
        preds = model(batch_data)
        y = batch_data.y.to(device).view(-1)
        loss = criterion(preds, y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * batch_data.num_graphs
        count += batch_data.num_graphs
    return total_loss / count if count > 0 else 0.0

def validate(model, loader, criterion, device):
    model.eval()
    total_loss = 0.0
    count = 0
    with torch.no_grad():
        for batch_data in loader:
            batch_data = batch_data.to(device)
            preds = model(batch_data)
            y = batch_data.y.to(device).view(-1)
            loss = criterion(preds, y)
            total_loss += loss.item() * batch_data.num_graphs
            count += batch_data.num_graphs
    return total_loss / count if count > 0 else 0.0

def evaluate_model(model, loader, device):
    """
    Evaluate the model on a dataset loader and compute R² and RMSE.
    """
    model.eval()
    y_true, y_pred = [], []

    with torch.no_grad():
        for batch in loader:
            batch = batch.to(device)
            preds = model(batch)
            y_true.append(batch.y.cpu())
            y_pred.append(preds.cpu())

    y_true = torch.cat(y_true).numpy().squeeze()
    y_pred = torch.cat(y_pred).numpy().squeeze()

    r2 = r2_score(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))

    print(f"R²: {r2:.4f}")
    print(f"RMSE: {rmse:.4f}")

    return r2, rmse

# =============================================================================
#                             DATA PREPARATION
# =============================================================================

env_file = r"F:\2025 energing\PYTHON\GNN_chemicalENV-main\GNN molecules\graph_pickles\dataset02.xlsx"
data = pd.read_excel(env_file, engine='openpyxl').dropna(subset=['degradation_rate'])
data['seawater'] = data['seawater'].map({'art': 1, 'sea': 0})

folder_path = r"F:\2025 energing\PYTHON\GNN_chemicalENV-main\GNN molecules\graph_pickles\molecules"
graph_pickles = [f for f in os.listdir(folder_path) if f.endswith(".pkl")]

base_dir = r"F:\2025 energing\PYTHON\GNN_chemicalENV-main\GNN molecules\graph_pickles\molecules"
if os.path.exists(base_dir):
    print("Directory exists:", base_dir)
    print("Files in directory:", os.listdir(base_dir))
else:
    print(f"Error: Directory {base_dir} does not exist!")

compounds = data.component.unique()
graphs_dict = {}
for compound, graph_pickle in zip(compounds, graph_pickles):
    with open(os.path.join(base_dir, graph_pickle), 'rb') as f:
        graph = pickle.load(f)
        graphs_dict[compound] = networkx_to_pyg(graph)

dataset = MolDataset(
    raw_dataframe=data,
    nx_graph_dict=graphs_dict,
    component_col="component",
    global_state_cols=["temperature", "concentration", "time", "seawater"],
    label_col="degradation_rate",
    transform=None
)

# =============================================================================
#                      GRID SEARCH WITH CROSS-VALIDATION
# =============================================================================

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Hyperparameters settings to test:
#   - hidden_dim: 16 and 200
#   - num_layers: always 4
#   - dropout: 0 (disabled)
#   - batch_size: 16 and 64
#   - weight_decay: with (1e-5) and without (0)
#   - learning rate: 1e-3 (constant)
hidden_dims = [16, 200]
batch_sizes = [16, 64]
weight_decays = [1e-5, 0]
num_layers = 4
dropout_value = 0.0
learning_rate = 1e-3
num_epochs = 500
num_folds = 5
num_repetitions = 10

# Dictionary to store the final results for each parameter combination
grid_search_results = []

# Loop over each grid search parameter combination
for hid_dim in hidden_dims:
    for batch_size in batch_sizes:
        for weight_decay in weight_decays:
            print("\n==========================================")
            print(f"Starting grid search for: hidden_dim={hid_dim}, batch_size={batch_size}, weight_decay={weight_decay}")
            print("==========================================\n")
            # List to record results for each repetition (10 times)
            all_repetition_results = []
            
            for rep in range(1, num_repetitions + 1):
                print(f"\n--- Repetition {rep} ---")
                # List to hold fold results for current repetition
                fold_results = []
                
                # 5-fold CV: Using KFold without fixed random_state (so each repetition is random)
                kf = KFold(n_splits=num_folds, shuffle=True)
                fold = 0
                for train_idx, val_idx in kf.split(dataset):
                    fold += 1
                    print(f"\n--- Repetition {rep} - Fold {fold} ---")
                    train_subset = torch.utils.data.Subset(dataset, train_idx)
                    val_subset = torch.utils.data.Subset(dataset, val_idx)
                    
                    # Create data loaders with current batch_size
                    train_loader = PyGDataLoader(train_subset, batch_size=batch_size, shuffle=True)
                    val_loader = PyGDataLoader(val_subset, batch_size=batch_size, shuffle=False)
                    
                    # Instantiate the model with current hidden_dim, num_layers and dropout
                    model = GINE_Regression(
                        node_in_dim=1,
                        edge_in_dim=2,
                        external_in_dim=4,
                        hidden_dim=hid_dim,
                        num_layers=num_layers,
                        dropout=dropout_value
                    ).to(device)
                    
                    # Setup optimizer with current weight_decay and learning_rate
                    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
                    criterion = torch.nn.MSELoss()
                    
                    # Training loop for the given number of epochs
                    for epoch in range(1, num_epochs + 1):
                        train_loss = train_one_epoch(model, train_loader, optimizer, criterion, device)
                        val_loss = validate(model, val_loader, criterion, device)
                        
                        if epoch % 10 == 0:
                            print(f"[Rep {rep} Fold {fold} Epoch {epoch}] Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
                    
                    print(f"Evaluating Rep {rep} Fold {fold} ...")
                    r2, rmse = evaluate_model(model, val_loader, device)
                    fold_results.append({"fold": fold, "r2": r2, "rmse": rmse})
                
                # After all folds, compute average results for this repetition
                r2_scores = [res["r2"] for res in fold_results]
                rmse_scores = [res["rmse"] for res in fold_results]
                rep_result = {
                    "repetition": rep,
                    "mean_r2": np.mean(r2_scores),
                    "std_r2": np.std(r2_scores),
                    "mean_rmse": np.mean(rmse_scores),
                    "std_rmse": np.std(rmse_scores)
                }
                print(f"\n--- Repetition {rep} Summary ---")
                print(f"Mean R²: {rep_result['mean_r2']:.4f} ± {rep_result['std_r2']:.4f}")
                print(f"Mean RMSE: {rep_result['mean_rmse']:.4f} ± {rep_result['std_rmse']:.4f}")
                all_repetition_results.append(rep_result)
            
            # Aggregate results over all repetitions for this grid search configuration
            rep_r2_scores = [res["mean_r2"] for res in all_repetition_results]
            rep_rmse_scores = [res["mean_rmse"] for res in all_repetition_results]
            grid_result = {
                "hidden_dim": hid_dim,
                "batch_size": batch_size,
                "weight_decay": weight_decay,
                "mean_r2_overall": np.mean(rep_r2_scores),
                "std_r2_overall": np.std(rep_r2_scores),
                "mean_rmse_overall": np.mean(rep_rmse_scores),
                "std_rmse_overall": np.std(rep_rmse_scores)
            }
            grid_search_results.append(grid_result)
            
            print("\n--- Grid Search Summary for this configuration ---")
            print(f"hidden_dim: {hid_dim}, batch_size: {batch_size}, weight_decay: {weight_decay}")
            print(f"Overall Mean R²: {grid_result['mean_r2_overall']:.4f} ± {grid_result['std_r2_overall']:.4f}")
            print(f"Overall Mean RMSE: {grid_result['mean_rmse_overall']:.4f} ± {grid_result['std_rmse_overall']:.4f}")

print("\n==========================================")
print("FINAL GRID SEARCH RESULTS")
print("==========================================\n")
for res in grid_search_results:
    print(f"Configuration: hidden_dim={res['hidden_dim']}, batch_size={res['batch_size']}, weight_decay={res['weight_decay']}")
    print(f"Overall Mean R²: {res['mean_r2_overall']:.4f} ± {res['std_r2_overall']:.4f}")
    print(f"Overall Mean RMSE: {res['mean_rmse_overall']:.4f} ± {res['std_rmse_overall']:.4f}\n")
# Out:
# Directory exists: F:\2025 energing\PYTHON\GNN_chemicalENV-main\GNN molecules\graph_pickles\molecules
# Files in directory: ['gpickle_graph_0.pkl', 'gpickle_graph_1.pkl', 'gpickle_graph_10.pkl', 'gpickle_graph_11.pkl', 'gpickle_graph_12.pkl', 'gpickle_graph_13.pkl', 'gpickle_graph_14.pkl', 'gpickle_graph_15.pkl', 'gpickle_graph_16.pkl', 'gpickle_graph_17.pkl', 'gpickle_graph_18.pkl', 'gpickle_graph_19.pkl', 'gpickle_graph_2.pkl', 'gpickle_graph_3.pkl', 'gpickle_graph_4.pkl', 'gpickle_graph_5.pkl', 'gpickle_graph_6.pkl', 'gpickle_graph_7.pkl', 'gpickle_graph_8.pkl', 'gpickle_graph_9.pkl']
#
# ==========================================
# Starting grid search for: hidden_dim=16, batch_size=16, weight_decay=1e-05
# ==========================================
#
#
# --- Repetition 1 ---
#
# --- Repetition 1 - Fold 1 ---
# [Rep 1 Fold 1 Epoch 10] Train Loss: 0.0805 | Val Loss: 0.0603
# [Rep 1 Fold 1 Epoch 20] Train Loss: 0.0593 | Val Loss: 0.0511
# [Rep 1 Fold 1 Epoch 30] Train Loss: 0.0762 | Val Loss: 0.0618
# [Rep 1 Fold 1 Epoch 40] Train Loss: 0.0546 | Val Loss: 0.0546
# [Rep 1 Fold 1 Epoch 50] Train Loss: 0.0759 | Val Loss: 0.1341
# [Rep 1 Fold 1 Epoch 60] Train Loss: 0.0600 | Val Loss: 0.0585
# [Rep 1 Fold 1 Epoch 70] Train Loss: 0.0600 | Val Loss: 0.0454
# [Rep 1 Fold 1 Epoch 80] Train Loss: 0.0583 | Val Loss: 0.0413
# [Rep 1 Fold 1 Epoch 90] Train Loss: 0.0561 | Val Loss: 0.0508
# [Rep 1 Fold 1 Epoch 100] Train Loss: 0.0519 | Val Loss: 0.0634
# [Rep 1 Fold 1 Epoch 110] Train Loss: 0.0482 | Val Loss: 0.0405
# [Rep 1 Fold 1 Epoch 120] Train Loss: 0.0540 | Val Loss: 0.0545
# [Rep 1 Fold 1 Epoch 130] Train Loss: 0.0462 | Val Loss: 0.0385
# [Rep 1 Fold 1 Epoch 140] Train Loss: 0.0523 | Val Loss: 0.0402
# [Rep 1 Fold 1 Epoch 150] Train Loss: 0.0411 | Val Loss: 0.0408
# [Rep 1 Fold 1 Epoch 160] Train Loss: 0.0539 | Val Loss: 0.0494
# [Rep 1 Fold 1 Epoch 170] Train Loss: 0.0500 | Val Loss: 0.0486
# [Rep 1 Fold 1 Epoch 180] Train Loss: 0.0566 | Val Loss: 0.0500
# [Rep 1 Fold 1 Epoch 190] Train Loss: 0.0468 | Val Loss: 0.0356
# [Rep 1 Fold 1 Epoch 200] Train Loss: 0.0428 | Val Loss: 0.0338
# [Rep 1 Fold 1 Epoch 210] Train Loss: 0.0438 | Val Loss: 0.0350
# [Rep 1 Fold 1 Epoch 220] Train Loss: 0.0457 | Val Loss: 0.0389
# [Rep 1 Fold 1 Epoch 230] Train Loss: 0.0442 | Val Loss: 0.0491
# [Rep 1 Fold 1 Epoch 240] Train Loss: 0.0410 | Val Loss: 0.0331
# [Rep 1 Fold 1 Epoch 250] Train Loss: 0.0397 | Val Loss: 0.0351
# [Rep 1 Fold 1 Epoch 260] Train Loss: 0.0468 | Val Loss: 0.2222
# [Rep 1 Fold 1 Epoch 270] Train Loss: 0.0396 | Val Loss: 0.0354
# [Rep 1 Fold 1 Epoch 280] Train Loss: 0.0418 | Val Loss: 0.0299
# [Rep 1 Fold 1 Epoch 290] Train Loss: 0.0404 | Val Loss: 0.0309
# [Rep 1 Fold 1 Epoch 300] Train Loss: 0.0372 | Val Loss: 0.0515
# [Rep 1 Fold 1 Epoch 310] Train Loss: 0.0346 | Val Loss: 0.2380
# [Rep 1 Fold 1 Epoch 320] Train Loss: 0.0361 | Val Loss: 0.0705
# [Rep 1 Fold 1 Epoch 330] Train Loss: 0.0394 | Val Loss: 0.0315
# [Rep 1 Fold 1 Epoch 340] Train Loss: 0.0349 | Val Loss: 0.2475
# [Rep 1 Fold 1 Epoch 350] Train Loss: 0.0361 | Val Loss: 0.0381
# [Rep 1 Fold 1 Epoch 360] Train Loss: 0.0334 | Val Loss: 0.0844
# [Rep 1 Fold 1 Epoch 370] Train Loss: 0.0396 | Val Loss: 0.0375
# [Rep 1 Fold 1 Epoch 380] Train Loss: 0.0316 | Val Loss: 0.0409
# [Rep 1 Fold 1 Epoch 390] Train Loss: 0.0281 | Val Loss: 0.0340
# [Rep 1 Fold 1 Epoch 400] Train Loss: 0.0337 | Val Loss: 0.0368
# [Rep 1 Fold 1 Epoch 410] Train Loss: 0.0363 | Val Loss: 0.0331
# [Rep 1 Fold 1 Epoch 420] Train Loss: 0.0343 | Val Loss: 0.1749
# [Rep 1 Fold 1 Epoch 430] Train Loss: 0.0339 | Val Loss: 0.1209
# [Rep 1 Fold 1 Epoch 440] Train Loss: 0.0344 | Val Loss: 0.0285
# [Rep 1 Fold 1 Epoch 450] Train Loss: 0.0301 | Val Loss: 0.0313
# [Rep 1 Fold 1 Epoch 460] Train Loss: 0.0290 | Val Loss: 0.0329
# [Rep 1 Fold 1 Epoch 470] Train Loss: 0.0348 | Val Loss: 0.0319
# [Rep 1 Fold 1 Epoch 480] Train Loss: 0.0329 | Val Loss: 0.0283
# [Rep 1 Fold 1 Epoch 490] Train Loss: 0.0350 | Val Loss: 0.0504
# [Rep 1 Fold 1 Epoch 500] Train Loss: 0.0362 | Val Loss: 0.4904
# Evaluating Rep 1 Fold 1 ...
# R²: -5.5785
# RMSE: 0.7003
#
# --- Repetition 1 - Fold 2 ---
# [Rep 1 Fold 2 Epoch 10] Train Loss: 0.0877 | Val Loss: 0.1226
# [Rep 1 Fold 2 Epoch 20] Train Loss: 0.0660 | Val Loss: 0.0671
# [Rep 1 Fold 2 Epoch 30] Train Loss: 0.0572 | Val Loss: 0.0767
# [Rep 1 Fold 2 Epoch 40] Train Loss: 0.0702 | Val Loss: 0.0779
# [Rep 1 Fold 2 Epoch 50] Train Loss: 0.0759 | Val Loss: 0.0537
# [Rep 1 Fold 2 Epoch 60] Train Loss: 0.0580 | Val Loss: 0.0530
# [Rep 1 Fold 2 Epoch 70] Train Loss: 0.0658 | Val Loss: 0.1649
# [Rep 1 Fold 2 Epoch 80] Train Loss: 0.0753 | Val Loss: 0.0476
# [Rep 1 Fold 2 Epoch 90] Train Loss: 0.0501 | Val Loss: 0.0506
# [Rep 1 Fold 2 Epoch 100] Train Loss: 0.0567 | Val Loss: 0.0488
# [Rep 1 Fold 2 Epoch 110] Train Loss: 0.0498 | Val Loss: 0.0549
# [Rep 1 Fold 2 Epoch 120] Train Loss: 0.0433 | Val Loss: 0.0981
# [Rep 1 Fold 2 Epoch 130] Train Loss: 0.0418 | Val Loss: 0.0718
# [Rep 1 Fold 2 Epoch 140] Train Loss: 0.0519 | Val Loss: 0.0706
# [Rep 1 Fold 2 Epoch 150] Train Loss: 0.0452 | Val Loss: 0.0427
# [Rep 1 Fold 2 Epoch 160] Train Loss: 0.0456 | Val Loss: 0.0788
# [Rep 1 Fold 2 Epoch 170] Train Loss: 0.0434 | Val Loss: 0.1588
# [Rep 1 Fold 2 Epoch 180] Train Loss: 0.0416 | Val Loss: 0.0394
# [Rep 1 Fold 2 Epoch 190] Train Loss: 0.0412 | Val Loss: 0.0938
# [Rep 1 Fold 2 Epoch 200] Train Loss: 0.0374 | Val Loss: 0.0511
# [Rep 1 Fold 2 Epoch 210] Train Loss: 0.0457 | Val Loss: 0.0519
# [Rep 1 Fold 2 Epoch 220] Train Loss: 0.0361 | Val Loss: 0.0398
# [Rep 1 Fold 2 Epoch 230] Train Loss: 0.0366 | Val Loss: 0.0376
# [Rep 1 Fold 2 Epoch 240] Train Loss: 0.0525 | Val Loss: 0.1428
# [Rep 1 Fold 2 Epoch 250] Train Loss: 0.0398 | Val Loss: 0.0380
# [Rep 1 Fold 2 Epoch 260] Train Loss: 0.0385 | Val Loss: 0.0556
# [Rep 1 Fold 2 Epoch 270] Train Loss: 0.0382 | Val Loss: 0.0752
# [Rep 1 Fold 2 Epoch 280] Train Loss: 0.0426 | Val Loss: 0.0511
# [Rep 1 Fold 2 Epoch 290] Train Loss: 0.0402 | Val Loss: 0.0655
# [Rep 1 Fold 2 Epoch 300] Train Loss: 0.0351 | Val Loss: 0.0623
# [Rep 1 Fold 2 Epoch 310] Train Loss: 0.0392 | Val Loss: 0.0611
# [Rep 1 Fold 2 Epoch 320] Train Loss: 0.0426 | Val Loss: 0.0369
# [Rep 1 Fold 2 Epoch 330] Train Loss: 0.0364 | Val Loss: 0.0402
# [Rep 1 Fold 2 Epoch 340] Train Loss: 0.0383 | Val Loss: 0.0457
# [Rep 1 Fold 2 Epoch 350] Train Loss: 0.0457 | Val Loss: 0.0835
# [Rep 1 Fold 2 Epoch 360] Train Loss: 0.0390 | Val Loss: 0.0382
# [Rep 1 Fold 2 Epoch 370] Train Loss: 0.0389 | Val Loss: 0.0382
# [Rep 1 Fold 2 Epoch 380] Train Loss: 0.0406 | Val Loss: 0.0406
# [Rep 1 Fold 2 Epoch 390] Train Loss: 0.0424 | Val Loss: 0.0386
# [Rep 1 Fold 2 Epoch 400] Train Loss: 0.0373 | Val Loss: 0.0383
# [Rep 1 Fold 2 Epoch 410] Train Loss: 0.0350 | Val Loss: 0.0476
# [Rep 1 Fold 2 Epoch 420] Train Loss: 0.0414 | Val Loss: 0.0420
# [Rep 1 Fold 2 Epoch 430] Train Loss: 0.0405 | Val Loss: 0.0407
# [Rep 1 Fold 2 Epoch 440] Train Loss: 0.0383 | Val Loss: 0.0450
# [Rep 1 Fold 2 Epoch 450] Train Loss: 0.0394 | Val Loss: 0.1309
# [Rep 1 Fold 2 Epoch 460] Train Loss: 0.0419 | Val Loss: 0.0640
# [Rep 1 Fold 2 Epoch 470] Train Loss: 0.0332 | Val Loss: 0.0406
# [Rep 1 Fold 2 Epoch 480] Train Loss: 0.0374 | Val Loss: 0.0676
# [Rep 1 Fold 2 Epoch 490] Train Loss: 0.0332 | Val Loss: 0.0411
# [Rep 1 Fold 2 Epoch 500] Train Loss: 0.0400 | Val Loss: 0.0558
# Evaluating Rep 1 Fold 2 ...
# R²: 0.2886
# RMSE: 0.2362
#
# --- Repetition 1 - Fold 3 ---
# [Rep 1 Fold 3 Epoch 10] Train Loss: 0.0680 | Val Loss: 0.0601
# [Rep 1 Fold 3 Epoch 20] Train Loss: 0.0891 | Val Loss: 0.1269
# [Rep 1 Fold 3 Epoch 30] Train Loss: 0.1767 | Val Loss: 0.0955
# [Rep 1 Fold 3 Epoch 40] Train Loss: 0.0825 | Val Loss: 0.0676
# [Rep 1 Fold 3 Epoch 50] Train Loss: 0.0549 | Val Loss: 0.0534
# [Rep 1 Fold 3 Epoch 60] Train Loss: 0.0600 | Val Loss: 0.0929
# [Rep 1 Fold 3 Epoch 70] Train Loss: 0.0432 | Val Loss: 0.0460
# [Rep 1 Fold 3 Epoch 80] Train Loss: 0.0573 | Val Loss: 0.0606
# [Rep 1 Fold 3 Epoch 90] Train Loss: 0.0532 | Val Loss: 0.0461
# [Rep 1 Fold 3 Epoch 100] Train Loss: 0.0412 | Val Loss: 0.0946
# [Rep 1 Fold 3 Epoch 110] Train Loss: 0.0466 | Val Loss: 0.0461
# [Rep 1 Fold 3 Epoch 120] Train Loss: 0.0413 | Val Loss: 0.0781
# [Rep 1 Fold 3 Epoch 130] Train Loss: 0.0411 | Val Loss: 0.0521
# [Rep 1 Fold 3 Epoch 140] Train Loss: 0.0481 | Val Loss: 0.0483
# [Rep 1 Fold 3 Epoch 150] Train Loss: 0.0495 | Val Loss: 0.0531
# [Rep 1 Fold 3 Epoch 160] Train Loss: 0.0454 | Val Loss: 0.0621
# [Rep 1 Fold 3 Epoch 170] Train Loss: 0.0392 | Val Loss: 0.0442
# [Rep 1 Fold 3 Epoch 180] Train Loss: 0.0376 | Val Loss: 0.0509
# [Rep 1 Fold 3 Epoch 190] Train Loss: 0.0492 | Val Loss: 0.0405
# [Rep 1 Fold 3 Epoch 200] Train Loss: 0.0367 | Val Loss: 0.0453
# [Rep 1 Fold 3 Epoch 210] Train Loss: 0.0394 | Val Loss: 0.0361
# [Rep 1 Fold 3 Epoch 220] Train Loss: 0.0363 | Val Loss: 0.0343
# [Rep 1 Fold 3 Epoch 230] Train Loss: 0.0361 | Val Loss: 0.0366
# [Rep 1 Fold 3 Epoch 240] Train Loss: 0.0357 | Val Loss: 0.0371
# [Rep 1 Fold 3 Epoch 250] Train Loss: 0.0384 | Val Loss: 0.0386
# [Rep 1 Fold 3 Epoch 260] Train Loss: 0.0327 | Val Loss: 0.0385
# [Rep 1 Fold 3 Epoch 270] Train Loss: 0.0321 | Val Loss: 0.0376
# [Rep 1 Fold 3 Epoch 280] Train Loss: 0.0309 | Val Loss: 0.0451
# [Rep 1 Fold 3 Epoch 290] Train Loss: 0.0300 | Val Loss: 0.0453
# [Rep 1 Fold 3 Epoch 300] Train Loss: 0.0375 | Val Loss: 0.0358
# [Rep 1 Fold 3 Epoch 310] Train Loss: 0.0325 | Val Loss: 0.0492
# [Rep 1 Fold 3 Epoch 320] Train Loss: 0.0346 | Val Loss: 0.0325
# [Rep 1 Fold 3 Epoch 330] Train Loss: 0.0369 | Val Loss: 0.0613
# [Rep 1 Fold 3 Epoch 340] Train Loss: 0.0344 | Val Loss: 0.0364
# [Rep 1 Fold 3 Epoch 350] Train Loss: 0.0381 | Val Loss: 0.0350
# [Rep 1 Fold 3 Epoch 360] Train Loss: 0.0349 | Val Loss: 0.0391
# [Rep 1 Fold 3 Epoch 370] Train Loss: 0.0296 | Val Loss: 0.0411
# [Rep 1 Fold 3 Epoch 380] Train Loss: 0.0303 | Val Loss: 0.0345
# [Rep 1 Fold 3 Epoch 390] Train Loss: 0.0358 | Val Loss: 0.0334
# [Rep 1 Fold 3 Epoch 400] Train Loss: 0.0307 | Val Loss: 0.0440
# [Rep 1 Fold 3 Epoch 410] Train Loss: 0.0342 | Val Loss: 0.0544
# [Rep 1 Fold 3 Epoch 420] Train Loss: 0.0330 | Val Loss: 0.0321
# [Rep 1 Fold 3 Epoch 430] Train Loss: 0.0306 | Val Loss: 0.0431
# [Rep 1 Fold 3 Epoch 440] Train Loss: 0.0318 | Val Loss: 0.0340
# [Rep 1 Fold 3 Epoch 450] Train Loss: 0.0322 | Val Loss: 0.0358
# [Rep 1 Fold 3 Epoch 460] Train Loss: 0.0285 | Val Loss: 0.0340
# [Rep 1 Fold 3 Epoch 470] Train Loss: 0.0377 | Val Loss: 0.0344
# [Rep 1 Fold 3 Epoch 480] Train Loss: 0.0302 | Val Loss: 0.0466
# [Rep 1 Fold 3 Epoch 490] Train Loss: 0.0316 | Val Loss: 0.0656
# [Rep 1 Fold 3 Epoch 500] Train Loss: 0.0328 | Val Loss: 0.0332
# Evaluating Rep 1 Fold 3 ...
# R²: 0.5390
# RMSE: 0.1823
#
# --- Repetition 1 - Fold 4 ---
# [Rep 1 Fold 4 Epoch 10] Train Loss: 0.0855 | Val Loss: 0.0592
# [Rep 1 Fold 4 Epoch 20] Train Loss: 0.0677 | Val Loss: 0.0403
# [Rep 1 Fold 4 Epoch 30] Train Loss: 0.0705 | Val Loss: 0.0961
# [Rep 1 Fold 4 Epoch 40] Train Loss: 0.0929 | Val Loss: 0.0591
# [Rep 1 Fold 4 Epoch 50] Train Loss: 0.0809 | Val Loss: 0.0648
# [Rep 1 Fold 4 Epoch 60] Train Loss: 0.0655 | Val Loss: 0.0582
# [Rep 1 Fold 4 Epoch 70] Train Loss: 0.0602 | Val Loss: 0.0441
# [Rep 1 Fold 4 Epoch 80] Train Loss: 0.0652 | Val Loss: 0.0918
# [Rep 1 Fold 4 Epoch 90] Train Loss: 0.0637 | Val Loss: 0.0415
# [Rep 1 Fold 4 Epoch 100] Train Loss: 0.0575 | Val Loss: 0.0504
# [Rep 1 Fold 4 Epoch 110] Train Loss: 0.0548 | Val Loss: 0.0382
# [Rep 1 Fold 4 Epoch 120] Train Loss: 0.0515 | Val Loss: 0.0420
# [Rep 1 Fold 4 Epoch 130] Train Loss: 0.0520 | Val Loss: 0.0390
# [Rep 1 Fold 4 Epoch 140] Train Loss: 0.0431 | Val Loss: 0.0424
# [Rep 1 Fold 4 Epoch 150] Train Loss: 0.0529 | Val Loss: 0.0416
# [Rep 1 Fold 4 Epoch 160] Train Loss: 0.0476 | Val Loss: 0.0373
# [Rep 1 Fold 4 Epoch 170] Train Loss: 0.0461 | Val Loss: 0.0491
# [Rep 1 Fold 4 Epoch 180] Train Loss: 0.0507 | Val Loss: 0.0396
# [Rep 1 Fold 4 Epoch 190] Train Loss: 0.0494 | Val Loss: 0.0407
# [Rep 1 Fold 4 Epoch 200] Train Loss: 0.0354 | Val Loss: 0.0332
# [Rep 1 Fold 4 Epoch 210] Train Loss: 0.0429 | Val Loss: 0.0320
# [Rep 1 Fold 4 Epoch 220] Train Loss: 0.0389 | Val Loss: 0.0379
# [Rep 1 Fold 4 Epoch 230] Train Loss: 0.0366 | Val Loss: 0.0324
# [Rep 1 Fold 4 Epoch 240] Train Loss: 0.0369 | Val Loss: 0.0342
# [Rep 1 Fold 4 Epoch 250] Train Loss: 0.0435 | Val Loss: 0.0350
# [Rep 1 Fold 4 Epoch 260] Train Loss: 0.0335 | Val Loss: 0.0338
# [Rep 1 Fold 4 Epoch 270] Train Loss: 0.0418 | Val Loss: 0.0336
# [Rep 1 Fold 4 Epoch 280] Train Loss: 0.0334 | Val Loss: 0.0317
# [Rep 1 Fold 4 Epoch 290] Train Loss: 0.0373 | Val Loss: 0.0338
# [Rep 1 Fold 4 Epoch 300] Train Loss: 0.0360 | Val Loss: 0.0339
# [Rep 1 Fold 4 Epoch 310] Train Loss: 0.0373 | Val Loss: 0.0319
# [Rep 1 Fold 4 Epoch 320] Train Loss: 0.0333 | Val Loss: 0.0313
# [Rep 1 Fold 4 Epoch 330] Train Loss: 0.0315 | Val Loss: 0.0334
# [Rep 1 Fold 4 Epoch 340] Train Loss: 0.0365 | Val Loss: 0.0334
# [Rep 1 Fold 4 Epoch 350] Train Loss: 0.0324 | Val Loss: 0.0316
# [Rep 1 Fold 4 Epoch 360] Train Loss: 0.0424 | Val Loss: 0.0368
# [Rep 1 Fold 4 Epoch 370] Train Loss: 0.0332 | Val Loss: 0.0365
# [Rep 1 Fold 4 Epoch 380] Train Loss: 0.0325 | Val Loss: 0.0317
# [Rep 1 Fold 4 Epoch 390] Train Loss: 0.0367 | Val Loss: 0.0318
# [Rep 1 Fold 4 Epoch 400] Train Loss: 0.0397 | Val Loss: 0.0336
# [Rep 1 Fold 4 Epoch 410] Train Loss: 0.0404 | Val Loss: 0.0447
# [Rep 1 Fold 4 Epoch 420] Train Loss: 0.0334 | Val Loss: 0.0324
# [Rep 1 Fold 4 Epoch 430] Train Loss: 0.0365 | Val Loss: 0.0311
# [Rep 1 Fold 4 Epoch 440] Train Loss: 0.0385 | Val Loss: 0.0302
# [Rep 1 Fold 4 Epoch 450] Train Loss: 0.0361 | Val Loss: 0.0337
# [Rep 1 Fold 4 Epoch 460] Train Loss: 0.0314 | Val Loss: 0.0318
# [Rep 1 Fold 4 Epoch 470] Train Loss: 0.0351 | Val Loss: 0.0317
# [Rep 1 Fold 4 Epoch 480] Train Loss: 0.0357 | Val Loss: 0.0365
# [Rep 1 Fold 4 Epoch 490] Train Loss: 0.0313 | Val Loss: 0.0317
# [Rep 1 Fold 4 Epoch 500] Train Loss: 0.0325 | Val Loss: 0.0310
# Evaluating Rep 1 Fold 4 ...
# R²: 0.4404
# RMSE: 0.1761
#
# --- Repetition 1 - Fold 5 ---
# [Rep 1 Fold 5 Epoch 10] Train Loss: 0.0620 | Val Loss: 0.0770
# [Rep 1 Fold 5 Epoch 20] Train Loss: 0.0631 | Val Loss: 0.0798
# [Rep 1 Fold 5 Epoch 30] Train Loss: 0.0577 | Val Loss: 0.0795
# [Rep 1 Fold 5 Epoch 40] Train Loss: 0.0487 | Val Loss: 0.0971
# [Rep 1 Fold 5 Epoch 50] Train Loss: 0.0623 | Val Loss: 0.1380
# [Rep 1 Fold 5 Epoch 60] Train Loss: 0.0587 | Val Loss: 0.1004
# [Rep 1 Fold 5 Epoch 70] Train Loss: 0.0481 | Val Loss: 0.0779
# [Rep 1 Fold 5 Epoch 80] Train Loss: 0.0559 | Val Loss: 0.0995
# [Rep 1 Fold 5 Epoch 90] Train Loss: 0.0528 | Val Loss: 0.0734
# [Rep 1 Fold 5 Epoch 100] Train Loss: 0.0667 | Val Loss: 0.1042
# [Rep 1 Fold 5 Epoch 110] Train Loss: 0.0665 | Val Loss: 0.0811
# [Rep 1 Fold 5 Epoch 120] Train Loss: 0.0559 | Val Loss: 0.0739
# [Rep 1 Fold 5 Epoch 130] Train Loss: 0.0519 | Val Loss: 0.0788
# [Rep 1 Fold 5 Epoch 140] Train Loss: 0.0623 | Val Loss: 0.0800
# [Rep 1 Fold 5 Epoch 150] Train Loss: 0.0495 | Val Loss: 0.0752
# [Rep 1 Fold 5 Epoch 160] Train Loss: 0.0473 | Val Loss: 0.0727
# [Rep 1 Fold 5 Epoch 170] Train Loss: 0.0587 | Val Loss: 0.0902
# [Rep 1 Fold 5 Epoch 180] Train Loss: 0.0526 | Val Loss: 0.0705
# [Rep 1 Fold 5 Epoch 190] Train Loss: 0.0543 | Val Loss: 0.0776
# [Rep 1 Fold 5 Epoch 200] Train Loss: 0.0534 | Val Loss: 0.0678
# [Rep 1 Fold 5 Epoch 210] Train Loss: 0.0536 | Val Loss: 0.0681
# [Rep 1 Fold 5 Epoch 220] Train Loss: 0.0499 | Val Loss: 0.0782
# [Rep 1 Fold 5 Epoch 230] Train Loss: 0.0463 | Val Loss: 0.0725
# [Rep 1 Fold 5 Epoch 240] Train Loss: 0.0466 | Val Loss: 0.0662
# [Rep 1 Fold 5 Epoch 250] Train Loss: 0.0529 | Val Loss: 0.0652
# [Rep 1 Fold 5 Epoch 260] Train Loss: 0.0478 | Val Loss: 0.0737
# [Rep 1 Fold 5 Epoch 270] Train Loss: 0.0482 | Val Loss: 0.0709
# [Rep 1 Fold 5 Epoch 280] Train Loss: 0.0473 | Val Loss: 0.0567
# [Rep 1 Fold 5 Epoch 290] Train Loss: 0.0507 | Val Loss: 0.0559
# [Rep 1 Fold 5 Epoch 300] Train Loss: 0.0469 | Val Loss: 0.0621
# [Rep 1 Fold 5 Epoch 310] Train Loss: 0.0405 | Val Loss: 0.0613
# [Rep 1 Fold 5 Epoch 320] Train Loss: 0.0411 | Val Loss: 0.0537
# [Rep 1 Fold 5 Epoch 330] Train Loss: 0.0402 | Val Loss: 0.0511
# [Rep 1 Fold 5 Epoch 340] Train Loss: 0.0333 | Val Loss: 0.0565
# [Rep 1 Fold 5 Epoch 350] Train Loss: 0.0378 | Val Loss: 0.0525
# [Rep 1 Fold 5 Epoch 360] Train Loss: 0.0451 | Val Loss: 0.0543
# [Rep 1 Fold 5 Epoch 370] Train Loss: 0.0354 | Val Loss: 0.0511
# [Rep 1 Fold 5 Epoch 380] Train Loss: 0.0353 | Val Loss: 0.0453
# [Rep 1 Fold 5 Epoch 390] Train Loss: 0.0361 | Val Loss: 0.0449
# [Rep 1 Fold 5 Epoch 400] Train Loss: 0.0316 | Val Loss: 0.0503
# [Rep 1 Fold 5 Epoch 410] Train Loss: 0.0434 | Val Loss: 0.0829
# [Rep 1 Fold 5 Epoch 420] Train Loss: 0.0365 | Val Loss: 0.0451
# [Rep 1 Fold 5 Epoch 430] Train Loss: 0.0456 | Val Loss: 0.0455
# [Rep 1 Fold 5 Epoch 440] Train Loss: 0.0378 | Val Loss: 0.0427
# [Rep 1 Fold 5 Epoch 450] Train Loss: 0.0363 | Val Loss: 0.0400
# [Rep 1 Fold 5 Epoch 460] Train Loss: 0.0349 | Val Loss: 0.0424
# [Rep 1 Fold 5 Epoch 470] Train Loss: 0.0379 | Val Loss: 0.0465
# [Rep 1 Fold 5 Epoch 480] Train Loss: 0.0303 | Val Loss: 0.0538
# [Rep 1 Fold 5 Epoch 490] Train Loss: 0.0322 | Val Loss: 0.0429
# [Rep 1 Fold 5 Epoch 500] Train Loss: 0.0306 | Val Loss: 0.0431
# Evaluating Rep 1 Fold 5 ...
# R²: 0.5801
# RMSE: 0.2077
#
# --- Repetition 1 Summary ---
# Mean R²: -0.7461 ± 2.4183
# Mean RMSE: 0.3005 ± 0.2010
#
# --- Repetition 2 ---
#
# --- Repetition 2 - Fold 1 ---
# [Rep 2 Fold 1 Epoch 10] Train Loss: 0.0812 | Val Loss: 0.0901
# [Rep 2 Fold 1 Epoch 20] Train Loss: 0.0963 | Val Loss: 0.0733
# [Rep 2 Fold 1 Epoch 30] Train Loss: 0.0711 | Val Loss: 0.0966
# [Rep 2 Fold 1 Epoch 40] Train Loss: 0.0720 | Val Loss: 0.0768
# [Rep 2 Fold 1 Epoch 50] Train Loss: 0.0681 | Val Loss: 0.1176
# [Rep 2 Fold 1 Epoch 60] Train Loss: 0.0788 | Val Loss: 0.0921
# [Rep 2 Fold 1 Epoch 70] Train Loss: 0.0556 | Val Loss: 0.0641
# [Rep 2 Fold 1 Epoch 80] Train Loss: 0.0520 | Val Loss: 0.0643
# [Rep 2 Fold 1 Epoch 90] Train Loss: 0.0633 | Val Loss: 0.0698
# [Rep 2 Fold 1 Epoch 100] Train Loss: 0.0597 | Val Loss: 0.0676
# [Rep 2 Fold 1 Epoch 110] Train Loss: 0.0559 | Val Loss: 0.0672
# [Rep 2 Fold 1 Epoch 120] Train Loss: 0.0541 | Val Loss: 0.0636
# [Rep 2 Fold 1 Epoch 130] Train Loss: 0.0595 | Val Loss: 0.0673
# [Rep 2 Fold 1 Epoch 140] Train Loss: 0.0538 | Val Loss: 0.0644
# [Rep 2 Fold 1 Epoch 150] Train Loss: 0.0476 | Val Loss: 0.0630
# [Rep 2 Fold 1 Epoch 160] Train Loss: 0.0457 | Val Loss: 0.0805
# [Rep 2 Fold 1 Epoch 170] Train Loss: 0.0487 | Val Loss: 0.0682
# [Rep 2 Fold 1 Epoch 180] Train Loss: 0.0539 | Val Loss: 0.0613
# [Rep 2 Fold 1 Epoch 190] Train Loss: 0.0402 | Val Loss: 0.0590
# [Rep 2 Fold 1 Epoch 200] Train Loss: 0.0455 | Val Loss: 0.0635
# [Rep 2 Fold 1 Epoch 210] Train Loss: 0.0436 | Val Loss: 0.0903
# [Rep 2 Fold 1 Epoch 220] Train Loss: 0.0452 | Val Loss: 0.1256
# [Rep 2 Fold 1 Epoch 230] Train Loss: 0.0450 | Val Loss: 0.0429
# [Rep 2 Fold 1 Epoch 240] Train Loss: 0.0374 | Val Loss: 0.0447
# [Rep 2 Fold 1 Epoch 250] Train Loss: 0.0462 | Val Loss: 0.0665
# [Rep 2 Fold 1 Epoch 260] Train Loss: 0.0477 | Val Loss: 0.0648
# [Rep 2 Fold 1 Epoch 270] Train Loss: 0.0383 | Val Loss: 0.0473
# [Rep 2 Fold 1 Epoch 280] Train Loss: 0.0401 | Val Loss: 0.0439
# [Rep 2 Fold 1 Epoch 290] Train Loss: 0.0407 | Val Loss: 0.0780
# [Rep 2 Fold 1 Epoch 300] Train Loss: 0.0401 | Val Loss: 0.0925
# [Rep 2 Fold 1 Epoch 310] Train Loss: 0.0398 | Val Loss: 0.0506
# [Rep 2 Fold 1 Epoch 320] Train Loss: 0.0442 | Val Loss: 0.0444
# [Rep 2 Fold 1 Epoch 330] Train Loss: 0.0462 | Val Loss: 0.1150
# [Rep 2 Fold 1 Epoch 340] Train Loss: 0.0420 | Val Loss: 0.0809
# [Rep 2 Fold 1 Epoch 350] Train Loss: 0.0401 | Val Loss: 0.0559
# [Rep 2 Fold 1 Epoch 360] Train Loss: 0.0328 | Val Loss: 0.0835
# [Rep 2 Fold 1 Epoch 370] Train Loss: 0.0388 | Val Loss: 0.0406
# [Rep 2 Fold 1 Epoch 380] Train Loss: 0.0451 | Val Loss: 0.0452
# [Rep 2 Fold 1 Epoch 390] Train Loss: 0.0337 | Val Loss: 0.0470
# [Rep 2 Fold 1 Epoch 400] Train Loss: 0.0387 | Val Loss: 0.0430
# [Rep 2 Fold 1 Epoch 410] Train Loss: 0.0337 | Val Loss: 0.0465
# [Rep 2 Fold 1 Epoch 420] Train Loss: 0.0388 | Val Loss: 0.0408
# [Rep 2 Fold 1 Epoch 430] Train Loss: 0.0344 | Val Loss: 0.0467
# [Rep 2 Fold 1 Epoch 440] Train Loss: 0.0383 | Val Loss: 0.0421
# [Rep 2 Fold 1 Epoch 450] Train Loss: 0.0399 | Val Loss: 0.0423
# [Rep 2 Fold 1 Epoch 460] Train Loss: 0.0374 | Val Loss: 0.0767
# [Rep 2 Fold 1 Epoch 470] Train Loss: 0.0350 | Val Loss: 0.0458
# [Rep 2 Fold 1 Epoch 480] Train Loss: 0.0378 | Val Loss: 0.0524
# [Rep 2 Fold 1 Epoch 490] Train Loss: 0.0325 | Val Loss: 0.1817
# [Rep 2 Fold 1 Epoch 500] Train Loss: 0.0365 | Val Loss: 0.0394
# Evaluating Rep 2 Fold 1 ...
# R²: 0.5766
# RMSE: 0.1985
#
# --- Repetition 2 - Fold 2 ---
# [Rep 2 Fold 2 Epoch 10] Train Loss: 0.0706 | Val Loss: 0.0627
# [Rep 2 Fold 2 Epoch 20] Train Loss: 0.0598 | Val Loss: 0.0507
# [Rep 2 Fold 2 Epoch 30] Train Loss: 0.0653 | Val Loss: 0.0639
# [Rep 2 Fold 2 Epoch 40] Train Loss: 0.0808 | Val Loss: 0.0583
# [Rep 2 Fold 2 Epoch 50] Train Loss: 0.0945 | Val Loss: 0.0971
# [Rep 2 Fold 2 Epoch 60] Train Loss: 0.0663 | Val Loss: 0.0571
# [Rep 2 Fold 2 Epoch 70] Train Loss: 0.0752 | Val Loss: 0.0538
# [Rep 2 Fold 2 Epoch 80] Train Loss: 0.0610 | Val Loss: 0.0479
# [Rep 2 Fold 2 Epoch 90] Train Loss: 0.0571 | Val Loss: 0.0734
# [Rep 2 Fold 2 Epoch 100] Train Loss: 0.0560 | Val Loss: 0.0546
# [Rep 2 Fold 2 Epoch 110] Train Loss: 0.0643 | Val Loss: 0.0487
# [Rep 2 Fold 2 Epoch 120] Train Loss: 0.0549 | Val Loss: 0.0465
# [Rep 2 Fold 2 Epoch 130] Train Loss: 0.0524 | Val Loss: 0.0624
# [Rep 2 Fold 2 Epoch 140] Train Loss: 0.0492 | Val Loss: 0.0462
# [Rep 2 Fold 2 Epoch 150] Train Loss: 0.0519 | Val Loss: 0.0911
# [Rep 2 Fold 2 Epoch 160] Train Loss: 0.0474 | Val Loss: 0.0391
# [Rep 2 Fold 2 Epoch 170] Train Loss: 0.0428 | Val Loss: 0.0473
# [Rep 2 Fold 2 Epoch 180] Train Loss: 0.0399 | Val Loss: 0.0490
# [Rep 2 Fold 2 Epoch 190] Train Loss: 0.0402 | Val Loss: 0.0319
# [Rep 2 Fold 2 Epoch 200] Train Loss: 0.0349 | Val Loss: 0.0299
# [Rep 2 Fold 2 Epoch 210] Train Loss: 0.0439 | Val Loss: 0.0301
# [Rep 2 Fold 2 Epoch 220] Train Loss: 0.0413 | Val Loss: 0.0304
# [Rep 2 Fold 2 Epoch 230] Train Loss: 0.0355 | Val Loss: 0.0330
# [Rep 2 Fold 2 Epoch 240] Train Loss: 0.0316 | Val Loss: 0.0384
# [Rep 2 Fold 2 Epoch 250] Train Loss: 0.0390 | Val Loss: 0.0285
# [Rep 2 Fold 2 Epoch 260] Train Loss: 0.0382 | Val Loss: 0.0336
# [Rep 2 Fold 2 Epoch 270] Train Loss: 0.0377 | Val Loss: 0.0294
# [Rep 2 Fold 2 Epoch 280] Train Loss: 0.0374 | Val Loss: 0.0297
# [Rep 2 Fold 2 Epoch 290] Train Loss: 0.0320 | Val Loss: 0.0299
# [Rep 2 Fold 2 Epoch 300] Train Loss: 0.0305 | Val Loss: 0.0284
# [Rep 2 Fold 2 Epoch 310] Train Loss: 0.0409 | Val Loss: 0.0293
# [Rep 2 Fold 2 Epoch 320] Train Loss: 0.0360 | Val Loss: 0.0279
# [Rep 2 Fold 2 Epoch 330] Train Loss: 0.0337 | Val Loss: 0.0316
# [Rep 2 Fold 2 Epoch 340] Train Loss: 0.0415 | Val Loss: 0.0372
# [Rep 2 Fold 2 Epoch 350] Train Loss: 0.0401 | Val Loss: 0.0284
# [Rep 2 Fold 2 Epoch 360] Train Loss: 0.0382 | Val Loss: 0.0321
# [Rep 2 Fold 2 Epoch 370] Train Loss: 0.0505 | Val Loss: 0.0360
# [Rep 2 Fold 2 Epoch 380] Train Loss: 0.0382 | Val Loss: 0.0465
# [Rep 2 Fold 2 Epoch 390] Train Loss: 0.0353 | Val Loss: 0.0315
# [Rep 2 Fold 2 Epoch 400] Train Loss: 0.0400 | Val Loss: 0.0376
# [Rep 2 Fold 2 Epoch 410] Train Loss: 0.0333 | Val Loss: 0.0306
# [Rep 2 Fold 2 Epoch 420] Train Loss: 0.0339 | Val Loss: 0.0415
# [Rep 2 Fold 2 Epoch 430] Train Loss: 0.0372 | Val Loss: 0.0332
# [Rep 2 Fold 2 Epoch 440] Train Loss: 0.0356 | Val Loss: 0.0276
# [Rep 2 Fold 2 Epoch 450] Train Loss: 0.0362 | Val Loss: 0.0294
# [Rep 2 Fold 2 Epoch 460] Train Loss: 0.0407 | Val Loss: 0.0293
# [Rep 2 Fold 2 Epoch 470] Train Loss: 0.0390 | Val Loss: 0.0302
# [Rep 2 Fold 2 Epoch 480] Train Loss: 0.0380 | Val Loss: 0.0269
# [Rep 2 Fold 2 Epoch 490] Train Loss: 0.0351 | Val Loss: 0.0261
# [Rep 2 Fold 2 Epoch 500] Train Loss: 0.0310 | Val Loss: 0.0324
# Evaluating Rep 2 Fold 2 ...
# R²: 0.5651
# RMSE: 0.1799
#
# --- Repetition 2 - Fold 3 ---
# [Rep 2 Fold 3 Epoch 10] Train Loss: 0.0671 | Val Loss: 0.0801
# [Rep 2 Fold 3 Epoch 20] Train Loss: 0.0528 | Val Loss: 0.0721
# [Rep 2 Fold 3 Epoch 30] Train Loss: 0.0606 | Val Loss: 0.0995
# [Rep 2 Fold 3 Epoch 40] Train Loss: 0.0540 | Val Loss: 0.0852
# [Rep 2 Fold 3 Epoch 50] Train Loss: 0.0652 | Val Loss: 0.0791
# [Rep 2 Fold 3 Epoch 60] Train Loss: 0.0589 | Val Loss: 0.0767
# [Rep 2 Fold 3 Epoch 70] Train Loss: 0.0579 | Val Loss: 0.0689
# [Rep 2 Fold 3 Epoch 80] Train Loss: 0.0555 | Val Loss: 0.0720
# [Rep 2 Fold 3 Epoch 90] Train Loss: 0.0667 | Val Loss: 0.0702
# [Rep 2 Fold 3 Epoch 100] Train Loss: 0.0581 | Val Loss: 0.0808
# [Rep 2 Fold 3 Epoch 110] Train Loss: 0.0458 | Val Loss: 0.0713
# [Rep 2 Fold 3 Epoch 120] Train Loss: 0.0509 | Val Loss: 0.1349
# [Rep 2 Fold 3 Epoch 130] Train Loss: 0.0426 | Val Loss: 0.0705
# [Rep 2 Fold 3 Epoch 140] Train Loss: 0.0515 | Val Loss: 0.0999
# [Rep 2 Fold 3 Epoch 150] Train Loss: 0.0426 | Val Loss: 0.2094
# [Rep 2 Fold 3 Epoch 160] Train Loss: 0.0447 | Val Loss: 0.1615
# [Rep 2 Fold 3 Epoch 170] Train Loss: 0.0443 | Val Loss: 0.3638
# [Rep 2 Fold 3 Epoch 180] Train Loss: 0.0491 | Val Loss: 0.0684
# [Rep 2 Fold 3 Epoch 190] Train Loss: 0.0580 | Val Loss: 0.1735
# [Rep 2 Fold 3 Epoch 200] Train Loss: 0.0465 | Val Loss: 0.0623
# [Rep 2 Fold 3 Epoch 210] Train Loss: 0.0472 | Val Loss: 0.0634
# [Rep 2 Fold 3 Epoch 220] Train Loss: 0.0483 | Val Loss: 0.0701
# [Rep 2 Fold 3 Epoch 230] Train Loss: 0.0455 | Val Loss: 0.0671
# [Rep 2 Fold 3 Epoch 240] Train Loss: 0.0409 | Val Loss: 0.0628
# [Rep 2 Fold 3 Epoch 250] Train Loss: 0.0385 | Val Loss: 0.0676
# [Rep 2 Fold 3 Epoch 260] Train Loss: 0.0362 | Val Loss: 0.1070
# [Rep 2 Fold 3 Epoch 270] Train Loss: 0.0415 | Val Loss: 0.0637
# [Rep 2 Fold 3 Epoch 280] Train Loss: 0.0338 | Val Loss: 0.0684
# [Rep 2 Fold 3 Epoch 290] Train Loss: 0.0343 | Val Loss: 0.0668
# [Rep 2 Fold 3 Epoch 300] Train Loss: 0.0383 | Val Loss: 0.0490
# [Rep 2 Fold 3 Epoch 310] Train Loss: 0.0353 | Val Loss: 0.0547
# [Rep 2 Fold 3 Epoch 320] Train Loss: 0.0330 | Val Loss: 0.0625
# [Rep 2 Fold 3 Epoch 330] Train Loss: 0.0330 | Val Loss: 0.0494
# [Rep 2 Fold 3 Epoch 340] Train Loss: 0.0316 | Val Loss: 0.0572
# [Rep 2 Fold 3 Epoch 350] Train Loss: 0.0336 | Val Loss: 0.0615
# [Rep 2 Fold 3 Epoch 360] Train Loss: 0.0316 | Val Loss: 0.1943
# [Rep 2 Fold 3 Epoch 370] Train Loss: 0.0405 | Val Loss: 0.0474
# [Rep 2 Fold 3 Epoch 380] Train Loss: 0.0575 | Val Loss: 0.6341
# [Rep 2 Fold 3 Epoch 390] Train Loss: 0.0257 | Val Loss: 0.0503
# [Rep 2 Fold 3 Epoch 400] Train Loss: 0.0294 | Val Loss: 0.3382
# [Rep 2 Fold 3 Epoch 410] Train Loss: 0.0295 | Val Loss: 0.0829
# [Rep 2 Fold 3 Epoch 420] Train Loss: 0.0336 | Val Loss: 0.0742
# [Rep 2 Fold 3 Epoch 430] Train Loss: 0.0340 | Val Loss: 0.2143
# [Rep 2 Fold 3 Epoch 440] Train Loss: 0.0306 | Val Loss: 0.0560
# [Rep 2 Fold 3 Epoch 450] Train Loss: 0.0348 | Val Loss: 0.1005
# [Rep 2 Fold 3 Epoch 460] Train Loss: 0.0325 | Val Loss: 0.0463
# [Rep 2 Fold 3 Epoch 470] Train Loss: 0.0316 | Val Loss: 0.1162
# [Rep 2 Fold 3 Epoch 480] Train Loss: 0.0324 | Val Loss: 0.0511
# [Rep 2 Fold 3 Epoch 490] Train Loss: 0.0305 | Val Loss: 0.1409
# [Rep 2 Fold 3 Epoch 500] Train Loss: 0.0324 | Val Loss: 0.1076
# Evaluating Rep 2 Fold 3 ...
# R²: -0.4499
# RMSE: 0.3280
#
# --- Repetition 2 - Fold 4 ---
# [Rep 2 Fold 4 Epoch 10] Train Loss: 0.0663 | Val Loss: 0.0618
# [Rep 2 Fold 4 Epoch 20] Train Loss: 0.0670 | Val Loss: 0.0643
# [Rep 2 Fold 4 Epoch 30] Train Loss: 0.0687 | Val Loss: 0.0627
# [Rep 2 Fold 4 Epoch 40] Train Loss: 0.0692 | Val Loss: 0.1623
# [Rep 2 Fold 4 Epoch 50] Train Loss: 0.0640 | Val Loss: 0.0566
# [Rep 2 Fold 4 Epoch 60] Train Loss: 0.0650 | Val Loss: 0.0506
# [Rep 2 Fold 4 Epoch 70] Train Loss: 0.0559 | Val Loss: 0.2796
# [Rep 2 Fold 4 Epoch 80] Train Loss: 0.0590 | Val Loss: 0.0630
# [Rep 2 Fold 4 Epoch 90] Train Loss: 0.0633 | Val Loss: 0.0661
# [Rep 2 Fold 4 Epoch 100] Train Loss: 0.0488 | Val Loss: 0.0582
# [Rep 2 Fold 4 Epoch 110] Train Loss: 0.0514 | Val Loss: 0.0849
# [Rep 2 Fold 4 Epoch 120] Train Loss: 0.0437 | Val Loss: 0.0586
# [Rep 2 Fold 4 Epoch 130] Train Loss: 0.0527 | Val Loss: 0.0677
# [Rep 2 Fold 4 Epoch 140] Train Loss: 0.0440 | Val Loss: 0.0423
# [Rep 2 Fold 4 Epoch 150] Train Loss: 0.0462 | Val Loss: 0.0443
# [Rep 2 Fold 4 Epoch 160] Train Loss: 0.0435 | Val Loss: 0.0421
# [Rep 2 Fold 4 Epoch 170] Train Loss: 0.0500 | Val Loss: 0.0401
# [Rep 2 Fold 4 Epoch 180] Train Loss: 0.0470 | Val Loss: 0.0402
# [Rep 2 Fold 4 Epoch 190] Train Loss: 0.0405 | Val Loss: 0.0409
# [Rep 2 Fold 4 Epoch 200] Train Loss: 0.0440 | Val Loss: 0.0393
# [Rep 2 Fold 4 Epoch 210] Train Loss: 0.0413 | Val Loss: 0.0396
# [Rep 2 Fold 4 Epoch 220] Train Loss: 0.0426 | Val Loss: 0.0402
# [Rep 2 Fold 4 Epoch 230] Train Loss: 0.0419 | Val Loss: 0.0458
# [Rep 2 Fold 4 Epoch 240] Train Loss: 0.0540 | Val Loss: 0.0397
# [Rep 2 Fold 4 Epoch 250] Train Loss: 0.0434 | Val Loss: 0.0435
# [Rep 2 Fold 4 Epoch 260] Train Loss: 0.0385 | Val Loss: 0.0458
# [Rep 2 Fold 4 Epoch 270] Train Loss: 0.0348 | Val Loss: 0.0402
# [Rep 2 Fold 4 Epoch 280] Train Loss: 0.0387 | Val Loss: 0.0384
# [Rep 2 Fold 4 Epoch 290] Train Loss: 0.0392 | Val Loss: 0.0393
# [Rep 2 Fold 4 Epoch 300] Train Loss: 0.0365 | Val Loss: 0.0408
# [Rep 2 Fold 4 Epoch 310] Train Loss: 0.0396 | Val Loss: 0.0515
# [Rep 2 Fold 4 Epoch 320] Train Loss: 0.0367 | Val Loss: 0.0396
# [Rep 2 Fold 4 Epoch 330] Train Loss: 0.0337 | Val Loss: 0.0402
# [Rep 2 Fold 4 Epoch 340] Train Loss: 0.0364 | Val Loss: 0.0379
# [Rep 2 Fold 4 Epoch 350] Train Loss: 0.0375 | Val Loss: 0.0405
# [Rep 2 Fold 4 Epoch 360] Train Loss: 0.0330 | Val Loss: 0.0417
# [Rep 2 Fold 4 Epoch 370] Train Loss: 0.0392 | Val Loss: 0.0433
# [Rep 2 Fold 4 Epoch 380] Train Loss: 0.0321 | Val Loss: 0.1019
# [Rep 2 Fold 4 Epoch 390] Train Loss: 0.0319 | Val Loss: 0.0496
# [Rep 2 Fold 4 Epoch 400] Train Loss: 0.0409 | Val Loss: 0.0495
# [Rep 2 Fold 4 Epoch 410] Train Loss: 0.0374 | Val Loss: 0.0978
# [Rep 2 Fold 4 Epoch 420] Train Loss: 0.0380 | Val Loss: 0.0571
# [Rep 2 Fold 4 Epoch 430] Train Loss: 0.0356 | Val Loss: 0.0407
# [Rep 2 Fold 4 Epoch 440] Train Loss: 0.0303 | Val Loss: 0.0536
# [Rep 2 Fold 4 Epoch 450] Train Loss: 0.0324 | Val Loss: 0.0678
# [Rep 2 Fold 4 Epoch 460] Train Loss: 0.0317 | Val Loss: 0.0544
# [Rep 2 Fold 4 Epoch 470] Train Loss: 0.0323 | Val Loss: 0.0919
# [Rep 2 Fold 4 Epoch 480] Train Loss: 0.0282 | Val Loss: 0.0395
# [Rep 2 Fold 4 Epoch 490] Train Loss: 0.0323 | Val Loss: 0.0489
# [Rep 2 Fold 4 Epoch 500] Train Loss: 0.0312 | Val Loss: 0.0594
# Evaluating Rep 2 Fold 4 ...
# R²: 0.3278
# RMSE: 0.2438
#
# --- Repetition 2 - Fold 5 ---
# [Rep 2 Fold 5 Epoch 10] Train Loss: 0.0978 | Val Loss: 0.0916
# [Rep 2 Fold 5 Epoch 20] Train Loss: 0.0713 | Val Loss: 0.0626
# [Rep 2 Fold 5 Epoch 30] Train Loss: 0.0923 | Val Loss: 0.1336
# [Rep 2 Fold 5 Epoch 40] Train Loss: 0.0703 | Val Loss: 0.0478
# [Rep 2 Fold 5 Epoch 50] Train Loss: 0.0639 | Val Loss: 0.0476
# [Rep 2 Fold 5 Epoch 60] Train Loss: 0.0585 | Val Loss: 0.0594
# [Rep 2 Fold 5 Epoch 70] Train Loss: 0.0664 | Val Loss: 0.0447
# [Rep 2 Fold 5 Epoch 80] Train Loss: 0.0628 | Val Loss: 0.0588
# [Rep 2 Fold 5 Epoch 90] Train Loss: 0.0580 | Val Loss: 0.0669
# [Rep 2 Fold 5 Epoch 100] Train Loss: 0.0563 | Val Loss: 0.0672
# [Rep 2 Fold 5 Epoch 110] Train Loss: 0.0624 | Val Loss: 0.0588
# [Rep 2 Fold 5 Epoch 120] Train Loss: 0.0510 | Val Loss: 0.0497
# [Rep 2 Fold 5 Epoch 130] Train Loss: 0.0532 | Val Loss: 0.0445
# [Rep 2 Fold 5 Epoch 140] Train Loss: 0.0494 | Val Loss: 0.0407
# [Rep 2 Fold 5 Epoch 150] Train Loss: 0.0522 | Val Loss: 0.0400
# [Rep 2 Fold 5 Epoch 160] Train Loss: 0.0463 | Val Loss: 0.0435
# [Rep 2 Fold 5 Epoch 170] Train Loss: 0.0441 | Val Loss: 0.0482
# [Rep 2 Fold 5 Epoch 180] Train Loss: 0.0450 | Val Loss: 0.0399
# [Rep 2 Fold 5 Epoch 190] Train Loss: 0.0453 | Val Loss: 0.0415
# [Rep 2 Fold 5 Epoch 200] Train Loss: 0.0437 | Val Loss: 0.0591
# [Rep 2 Fold 5 Epoch 210] Train Loss: 0.0504 | Val Loss: 0.0409
# [Rep 2 Fold 5 Epoch 220] Train Loss: 0.0385 | Val Loss: 0.0347
# [Rep 2 Fold 5 Epoch 230] Train Loss: 0.0379 | Val Loss: 0.0391
# [Rep 2 Fold 5 Epoch 240] Train Loss: 0.0373 | Val Loss: 0.0329
# [Rep 2 Fold 5 Epoch 250] Train Loss: 0.0339 | Val Loss: 0.0343
# [Rep 2 Fold 5 Epoch 260] Train Loss: 0.0408 | Val Loss: 0.0310
# [Rep 2 Fold 5 Epoch 270] Train Loss: 0.0403 | Val Loss: 0.0302
# [Rep 2 Fold 5 Epoch 280] Train Loss: 0.0420 | Val Loss: 0.0337
# [Rep 2 Fold 5 Epoch 290] Train Loss: 0.0342 | Val Loss: 0.0341
# [Rep 2 Fold 5 Epoch 300] Train Loss: 0.0424 | Val Loss: 0.0337
# [Rep 2 Fold 5 Epoch 310] Train Loss: 0.0348 | Val Loss: 0.0310
# [Rep 2 Fold 5 Epoch 320] Train Loss: 0.0364 | Val Loss: 0.0306
# [Rep 2 Fold 5 Epoch 330] Train Loss: 0.0385 | Val Loss: 0.0318
# [Rep 2 Fold 5 Epoch 340] Train Loss: 0.0345 | Val Loss: 0.0307
# [Rep 2 Fold 5 Epoch 350] Train Loss: 0.0306 | Val Loss: 0.0293
# [Rep 2 Fold 5 Epoch 360] Train Loss: 0.0352 | Val Loss: 0.0552
# [Rep 2 Fold 5 Epoch 370] Train Loss: 0.0356 | Val Loss: 0.0309
# [Rep 2 Fold 5 Epoch 380] Train Loss: 0.0340 | Val Loss: 0.0294
# [Rep 2 Fold 5 Epoch 390] Train Loss: 0.0334 | Val Loss: 0.0300
# [Rep 2 Fold 5 Epoch 400] Train Loss: 0.0356 | Val Loss: 0.0312
# [Rep 2 Fold 5 Epoch 410] Train Loss: 0.0314 | Val Loss: 0.0282
# [Rep 2 Fold 5 Epoch 420] Train Loss: 0.0388 | Val Loss: 0.0288
# [Rep 2 Fold 5 Epoch 430] Train Loss: 0.0321 | Val Loss: 0.0314
# [Rep 2 Fold 5 Epoch 440] Train Loss: 0.0339 | Val Loss: 0.0284
# [Rep 2 Fold 5 Epoch 450] Train Loss: 0.0320 | Val Loss: 0.0295
# [Rep 2 Fold 5 Epoch 460] Train Loss: 0.0328 | Val Loss: 0.0446
# [Rep 2 Fold 5 Epoch 470] Train Loss: 0.0376 | Val Loss: 0.0323
# [Rep 2 Fold 5 Epoch 480] Train Loss: 0.0399 | Val Loss: 0.0331
# [Rep 2 Fold 5 Epoch 490] Train Loss: 0.0348 | Val Loss: 0.0376
# [Rep 2 Fold 5 Epoch 500] Train Loss: 0.0327 | Val Loss: 0.0281
# Evaluating Rep 2 Fold 5 ...
# R²: 0.5608
# RMSE: 0.1675
#
# --- Repetition 2 Summary ---
# Mean R²: 0.3161 ± 0.3941
# Mean RMSE: 0.2235 ± 0.0583
#
# --- Repetition 3 ---
#
# --- Repetition 3 - Fold 1 ---
# [Rep 3 Fold 1 Epoch 10] Train Loss: 0.0757 | Val Loss: 0.1878
# [Rep 3 Fold 1 Epoch 20] Train Loss: 0.0712 | Val Loss: 0.1437
# [Rep 3 Fold 1 Epoch 30] Train Loss: 0.0589 | Val Loss: 0.1591
# [Rep 3 Fold 1 Epoch 40] Train Loss: 0.0590 | Val Loss: 0.0592
# [Rep 3 Fold 1 Epoch 50] Train Loss: 0.0592 | Val Loss: 0.0636
# [Rep 3 Fold 1 Epoch 60] Train Loss: 0.0498 | Val Loss: 0.0558
# [Rep 3 Fold 1 Epoch 70] Train Loss: 0.0476 | Val Loss: 0.0549
# [Rep 3 Fold 1 Epoch 80] Train Loss: 0.0523 | Val Loss: 0.0569
# [Rep 3 Fold 1 Epoch 90] Train Loss: 0.0463 | Val Loss: 0.0563
# [Rep 3 Fold 1 Epoch 100] Train Loss: 0.0416 | Val Loss: 0.0549
# [Rep 3 Fold 1 Epoch 110] Train Loss: 0.0461 | Val Loss: 0.0597
# [Rep 3 Fold 1 Epoch 120] Train Loss: 0.0420 | Val Loss: 0.0874
# [Rep 3 Fold 1 Epoch 130] Train Loss: 0.0422 | Val Loss: 0.0515
# [Rep 3 Fold 1 Epoch 140] Train Loss: 0.0371 | Val Loss: 0.0557
# [Rep 3 Fold 1 Epoch 150] Train Loss: 0.0394 | Val Loss: 0.0530
# [Rep 3 Fold 1 Epoch 160] Train Loss: 0.0670 | Val Loss: 0.0698
# [Rep 3 Fold 1 Epoch 170] Train Loss: 0.0378 | Val Loss: 0.0526
# [Rep 3 Fold 1 Epoch 180] Train Loss: 0.0429 | Val Loss: 0.0538
# [Rep 3 Fold 1 Epoch 190] Train Loss: 0.0386 | Val Loss: 0.0677
# [Rep 3 Fold 1 Epoch 200] Train Loss: 0.0347 | Val Loss: 0.0469
# [Rep 3 Fold 1 Epoch 210] Train Loss: 0.0345 | Val Loss: 0.0473
# [Rep 3 Fold 1 Epoch 220] Train Loss: 0.0338 | Val Loss: 0.0552
# [Rep 3 Fold 1 Epoch 230] Train Loss: 0.0391 | Val Loss: 0.0489
# [Rep 3 Fold 1 Epoch 240] Train Loss: 0.0437 | Val Loss: 0.0610
# [Rep 3 Fold 1 Epoch 250] Train Loss: 0.0347 | Val Loss: 0.0484
# [Rep 3 Fold 1 Epoch 260] Train Loss: 0.0399 | Val Loss: 0.0492
# [Rep 3 Fold 1 Epoch 270] Train Loss: 0.0438 | Val Loss: 0.0489
# [Rep 3 Fold 1 Epoch 280] Train Loss: 0.0361 | Val Loss: 0.0646
# [Rep 3 Fold 1 Epoch 290] Train Loss: 0.0339 | Val Loss: 0.0503
# [Rep 3 Fold 1 Epoch 300] Train Loss: 0.0370 | Val Loss: 0.0669
# [Rep 3 Fold 1 Epoch 310] Train Loss: 0.0359 | Val Loss: 0.0533
# [Rep 3 Fold 1 Epoch 320] Train Loss: 0.0356 | Val Loss: 0.0439
# [Rep 3 Fold 1 Epoch 330] Train Loss: 0.0322 | Val Loss: 0.0558
# [Rep 3 Fold 1 Epoch 340] Train Loss: 0.0369 | Val Loss: 0.0436
# [Rep 3 Fold 1 Epoch 350] Train Loss: 0.0440 | Val Loss: 0.0452
# [Rep 3 Fold 1 Epoch 360] Train Loss: 0.0325 | Val Loss: 0.0441
# [Rep 3 Fold 1 Epoch 370] Train Loss: 0.0326 | Val Loss: 0.0441
# [Rep 3 Fold 1 Epoch 380] Train Loss: 0.0353 | Val Loss: 0.0466
# [Rep 3 Fold 1 Epoch 390] Train Loss: 0.0292 | Val Loss: 0.0433
# [Rep 3 Fold 1 Epoch 400] Train Loss: 0.0339 | Val Loss: 0.0678
# [Rep 3 Fold 1 Epoch 410] Train Loss: 0.0357 | Val Loss: 0.0436
# [Rep 3 Fold 1 Epoch 420] Train Loss: 0.0327 | Val Loss: 0.0484
# [Rep 3 Fold 1 Epoch 430] Train Loss: 0.0348 | Val Loss: 0.0438
# [Rep 3 Fold 1 Epoch 440] Train Loss: 0.0380 | Val Loss: 0.0438
# [Rep 3 Fold 1 Epoch 450] Train Loss: 0.0392 | Val Loss: 0.0446
# [Rep 3 Fold 1 Epoch 460] Train Loss: 0.0302 | Val Loss: 0.0423
# [Rep 3 Fold 1 Epoch 470] Train Loss: 0.0296 | Val Loss: 0.0414
# [Rep 3 Fold 1 Epoch 480] Train Loss: 0.0296 | Val Loss: 0.0419
# [Rep 3 Fold 1 Epoch 490] Train Loss: 0.0299 | Val Loss: 0.0468
# [Rep 3 Fold 1 Epoch 500] Train Loss: 0.0330 | Val Loss: 0.0399
# Evaluating Rep 3 Fold 1 ...
# R²: 0.5473
# RMSE: 0.1997
#
# --- Repetition 3 - Fold 2 ---
# [Rep 3 Fold 2 Epoch 10] Train Loss: 0.0650 | Val Loss: 0.0732
# [Rep 3 Fold 2 Epoch 20] Train Loss: 0.0788 | Val Loss: 0.0404
# [Rep 3 Fold 2 Epoch 30] Train Loss: 0.0884 | Val Loss: 0.0381
# [Rep 3 Fold 2 Epoch 40] Train Loss: 0.0674 | Val Loss: 0.0407
# [Rep 3 Fold 2 Epoch 50] Train Loss: 0.0782 | Val Loss: 0.0382
# [Rep 3 Fold 2 Epoch 60] Train Loss: 0.0832 | Val Loss: 0.1013
# [Rep 3 Fold 2 Epoch 70] Train Loss: 0.0804 | Val Loss: 0.0390
# [Rep 3 Fold 2 Epoch 80] Train Loss: 0.0719 | Val Loss: 0.0566
# [Rep 3 Fold 2 Epoch 90] Train Loss: 0.0534 | Val Loss: 0.0442
# [Rep 3 Fold 2 Epoch 100] Train Loss: 0.0634 | Val Loss: 0.0355
# [Rep 3 Fold 2 Epoch 110] Train Loss: 0.0533 | Val Loss: 0.0357
# [Rep 3 Fold 2 Epoch 120] Train Loss: 0.0550 | Val Loss: 0.0387
# [Rep 3 Fold 2 Epoch 130] Train Loss: 0.0553 | Val Loss: 0.0387
# [Rep 3 Fold 2 Epoch 140] Train Loss: 0.0587 | Val Loss: 0.0528
# [Rep 3 Fold 2 Epoch 150] Train Loss: 0.0538 | Val Loss: 0.0498
# [Rep 3 Fold 2 Epoch 160] Train Loss: 0.0556 | Val Loss: 0.0476
# [Rep 3 Fold 2 Epoch 170] Train Loss: 0.0583 | Val Loss: 0.0296
# [Rep 3 Fold 2 Epoch 180] Train Loss: 0.0481 | Val Loss: 0.0301
# [Rep 3 Fold 2 Epoch 190] Train Loss: 0.0520 | Val Loss: 0.0711
# [Rep 3 Fold 2 Epoch 200] Train Loss: 0.0517 | Val Loss: 0.0289
# [Rep 3 Fold 2 Epoch 210] Train Loss: 0.0429 | Val Loss: 0.0307
# [Rep 3 Fold 2 Epoch 220] Train Loss: 0.0542 | Val Loss: 0.0450
# [Rep 3 Fold 2 Epoch 230] Train Loss: 0.0391 | Val Loss: 0.0277
# [Rep 3 Fold 2 Epoch 240] Train Loss: 0.0481 | Val Loss: 0.0305
# [Rep 3 Fold 2 Epoch 250] Train Loss: 0.0445 | Val Loss: 0.0268
# [Rep 3 Fold 2 Epoch 260] Train Loss: 0.0423 | Val Loss: 0.0378
# [Rep 3 Fold 2 Epoch 270] Train Loss: 0.0435 | Val Loss: 0.0290
# [Rep 3 Fold 2 Epoch 280] Train Loss: 0.0413 | Val Loss: 0.0404
# [Rep 3 Fold 2 Epoch 290] Train Loss: 0.0440 | Val Loss: 0.0275
# [Rep 3 Fold 2 Epoch 300] Train Loss: 0.0446 | Val Loss: 0.0264
# [Rep 3 Fold 2 Epoch 310] Train Loss: 0.0452 | Val Loss: 0.0272
# [Rep 3 Fold 2 Epoch 320] Train Loss: 0.0459 | Val Loss: 0.0283
# [Rep 3 Fold 2 Epoch 330] Train Loss: 0.0404 | Val Loss: 0.0317
# [Rep 3 Fold 2 Epoch 340] Train Loss: 0.0453 | Val Loss: 0.0349
# [Rep 3 Fold 2 Epoch 350] Train Loss: 0.0414 | Val Loss: 0.0342
# [Rep 3 Fold 2 Epoch 360] Train Loss: 0.0452 | Val Loss: 0.0456
# [Rep 3 Fold 2 Epoch 370] Train Loss: 0.0409 | Val Loss: 0.0287
# [Rep 3 Fold 2 Epoch 380] Train Loss: 0.0385 | Val Loss: 0.0446
# [Rep 3 Fold 2 Epoch 390] Train Loss: 0.0482 | Val Loss: 0.0259
# [Rep 3 Fold 2 Epoch 400] Train Loss: 0.0376 | Val Loss: 0.0247
# [Rep 3 Fold 2 Epoch 410] Train Loss: 0.0420 | Val Loss: 0.0541
# [Rep 3 Fold 2 Epoch 420] Train Loss: 0.0339 | Val Loss: 0.0264
# [Rep 3 Fold 2 Epoch 430] Train Loss: 0.0392 | Val Loss: 0.0251
# [Rep 3 Fold 2 Epoch 440] Train Loss: 0.0352 | Val Loss: 0.0592
# [Rep 3 Fold 2 Epoch 450] Train Loss: 0.0391 | Val Loss: 0.0507
# [Rep 3 Fold 2 Epoch 460] Train Loss: 0.0410 | Val Loss: 0.0257
# [Rep 3 Fold 2 Epoch 470] Train Loss: 0.0427 | Val Loss: 0.0590
# [Rep 3 Fold 2 Epoch 480] Train Loss: 0.0431 | Val Loss: 0.0280
# [Rep 3 Fold 2 Epoch 490] Train Loss: 0.0443 | Val Loss: 0.0316
# [Rep 3 Fold 2 Epoch 500] Train Loss: 0.0380 | Val Loss: 0.0294
# Evaluating Rep 3 Fold 2 ...
# R²: 0.5144
# RMSE: 0.1714
#
# --- Repetition 3 - Fold 3 ---
# [Rep 3 Fold 3 Epoch 10] Train Loss: 0.0663 | Val Loss: 0.0946
# [Rep 3 Fold 3 Epoch 20] Train Loss: 0.0619 | Val Loss: 0.0692
# [Rep 3 Fold 3 Epoch 30] Train Loss: 0.0656 | Val Loss: 0.0621
# [Rep 3 Fold 3 Epoch 40] Train Loss: 0.0624 | Val Loss: 0.0856
# [Rep 3 Fold 3 Epoch 50] Train Loss: 0.0564 | Val Loss: 0.0689
# [Rep 3 Fold 3 Epoch 60] Train Loss: 0.0493 | Val Loss: 0.0603
# [Rep 3 Fold 3 Epoch 70] Train Loss: 0.0481 | Val Loss: 0.0563
# [Rep 3 Fold 3 Epoch 80] Train Loss: 0.0421 | Val Loss: 0.0538
# [Rep 3 Fold 3 Epoch 90] Train Loss: 0.0399 | Val Loss: 0.0569
# [Rep 3 Fold 3 Epoch 100] Train Loss: 0.0412 | Val Loss: 0.0549
# [Rep 3 Fold 3 Epoch 110] Train Loss: 0.0420 | Val Loss: 0.0545
# [Rep 3 Fold 3 Epoch 120] Train Loss: 0.0371 | Val Loss: 0.0490
# [Rep 3 Fold 3 Epoch 130] Train Loss: 0.0427 | Val Loss: 0.0545
# [Rep 3 Fold 3 Epoch 140] Train Loss: 0.0413 | Val Loss: 0.0472
# [Rep 3 Fold 3 Epoch 150] Train Loss: 0.0357 | Val Loss: 0.0494
# [Rep 3 Fold 3 Epoch 160] Train Loss: 0.0345 | Val Loss: 0.0459
# [Rep 3 Fold 3 Epoch 170] Train Loss: 0.0358 | Val Loss: 0.0465
# [Rep 3 Fold 3 Epoch 180] Train Loss: 0.0358 | Val Loss: 0.0436
# [Rep 3 Fold 3 Epoch 190] Train Loss: 0.0336 | Val Loss: 0.0491
# [Rep 3 Fold 3 Epoch 200] Train Loss: 0.0326 | Val Loss: 0.0513
# [Rep 3 Fold 3 Epoch 210] Train Loss: 0.0283 | Val Loss: 0.0434
# [Rep 3 Fold 3 Epoch 220] Train Loss: 0.0324 | Val Loss: 0.0451
# [Rep 3 Fold 3 Epoch 230] Train Loss: 0.0293 | Val Loss: 0.0454
# [Rep 3 Fold 3 Epoch 240] Train Loss: 0.0300 | Val Loss: 0.0429
# [Rep 3 Fold 3 Epoch 250] Train Loss: 0.0314 | Val Loss: 0.0457
# [Rep 3 Fold 3 Epoch 260] Train Loss: 0.0311 | Val Loss: 0.0505
# [Rep 3 Fold 3 Epoch 270] Train Loss: 0.0311 | Val Loss: 0.0443
# [Rep 3 Fold 3 Epoch 280] Train Loss: 0.0318 | Val Loss: 0.0445
# [Rep 3 Fold 3 Epoch 290] Train Loss: 0.0289 | Val Loss: 0.0476
# [Rep 3 Fold 3 Epoch 300] Train Loss: 0.0359 | Val Loss: 0.0422
# [Rep 3 Fold 3 Epoch 310] Train Loss: 0.0283 | Val Loss: 0.0439
# [Rep 3 Fold 3 Epoch 320] Train Loss: 0.0304 | Val Loss: 0.0450
# [Rep 3 Fold 3 Epoch 330] Train Loss: 0.0355 | Val Loss: 0.0447
# [Rep 3 Fold 3 Epoch 340] Train Loss: 0.0383 | Val Loss: 0.0429
# [Rep 3 Fold 3 Epoch 350] Train Loss: 0.0295 | Val Loss: 0.0437
# [Rep 3 Fold 3 Epoch 360] Train Loss: 0.0381 | Val Loss: 0.0463
# [Rep 3 Fold 3 Epoch 370] Train Loss: 0.0297 | Val Loss: 0.0419
# [Rep 3 Fold 3 Epoch 380] Train Loss: 0.0280 | Val Loss: 0.0436
# [Rep 3 Fold 3 Epoch 390] Train Loss: 0.0321 | Val Loss: 0.0459
# [Rep 3 Fold 3 Epoch 400] Train Loss: 0.0275 | Val Loss: 0.0461
# [Rep 3 Fold 3 Epoch 410] Train Loss: 0.0322 | Val Loss: 0.0412
# [Rep 3 Fold 3 Epoch 420] Train Loss: 0.0334 | Val Loss: 0.0442
# [Rep 3 Fold 3 Epoch 430] Train Loss: 0.0302 | Val Loss: 0.0414
# [Rep 3 Fold 3 Epoch 440] Train Loss: 0.0322 | Val Loss: 0.0406
# [Rep 3 Fold 3 Epoch 450] Train Loss: 0.0270 | Val Loss: 0.0418
# [Rep 3 Fold 3 Epoch 460] Train Loss: 0.0332 | Val Loss: 0.0426
# [Rep 3 Fold 3 Epoch 470] Train Loss: 0.0295 | Val Loss: 0.0464
# [Rep 3 Fold 3 Epoch 480] Train Loss: 0.0267 | Val Loss: 0.0439
# [Rep 3 Fold 3 Epoch 490] Train Loss: 0.0280 | Val Loss: 0.0418
# [Rep 3 Fold 3 Epoch 500] Train Loss: 0.0328 | Val Loss: 0.0435
# Evaluating Rep 3 Fold 3 ...
# R²: 0.4595
# RMSE: 0.2087
#
# --- Repetition 3 - Fold 4 ---
# [Rep 3 Fold 4 Epoch 10] Train Loss: 0.0793 | Val Loss: 0.0633
# [Rep 3 Fold 4 Epoch 20] Train Loss: 0.0604 | Val Loss: 0.0541
# [Rep 3 Fold 4 Epoch 30] Train Loss: 0.0544 | Val Loss: 0.0562
# [Rep 3 Fold 4 Epoch 40] Train Loss: 0.0655 | Val Loss: 0.0546
# [Rep 3 Fold 4 Epoch 50] Train Loss: 0.0607 | Val Loss: 0.0678
# [Rep 3 Fold 4 Epoch 60] Train Loss: 0.0961 | Val Loss: 0.0507
# [Rep 3 Fold 4 Epoch 70] Train Loss: 0.0716 | Val Loss: 0.0616
# [Rep 3 Fold 4 Epoch 80] Train Loss: 0.0643 | Val Loss: 0.0485
# [Rep 3 Fold 4 Epoch 90] Train Loss: 0.0578 | Val Loss: 0.0557
# [Rep 3 Fold 4 Epoch 100] Train Loss: 0.0670 | Val Loss: 0.0902
# [Rep 3 Fold 4 Epoch 110] Train Loss: 0.0609 | Val Loss: 0.0454
# [Rep 3 Fold 4 Epoch 120] Train Loss: 0.0523 | Val Loss: 0.0558
# [Rep 3 Fold 4 Epoch 130] Train Loss: 0.0547 | Val Loss: 0.0447
# [Rep 3 Fold 4 Epoch 140] Train Loss: 0.0555 | Val Loss: 0.0465
# [Rep 3 Fold 4 Epoch 150] Train Loss: 0.0478 | Val Loss: 0.0605
# [Rep 3 Fold 4 Epoch 160] Train Loss: 0.0479 | Val Loss: 0.0467
# [Rep 3 Fold 4 Epoch 170] Train Loss: 0.0532 | Val Loss: 0.1421
# [Rep 3 Fold 4 Epoch 180] Train Loss: 0.0460 | Val Loss: 0.0759
# [Rep 3 Fold 4 Epoch 190] Train Loss: 0.0486 | Val Loss: 0.0389
# [Rep 3 Fold 4 Epoch 200] Train Loss: 0.0515 | Val Loss: 0.0470
# [Rep 3 Fold 4 Epoch 210] Train Loss: 0.0481 | Val Loss: 0.0452
# [Rep 3 Fold 4 Epoch 220] Train Loss: 0.0482 | Val Loss: 0.0416
# [Rep 3 Fold 4 Epoch 230] Train Loss: 0.0516 | Val Loss: 0.0355
# [Rep 3 Fold 4 Epoch 240] Train Loss: 0.0426 | Val Loss: 0.0319
# [Rep 3 Fold 4 Epoch 250] Train Loss: 0.0423 | Val Loss: 0.0340
# [Rep 3 Fold 4 Epoch 260] Train Loss: 0.0457 | Val Loss: 0.0329
# [Rep 3 Fold 4 Epoch 270] Train Loss: 0.0421 | Val Loss: 0.0271
# [Rep 3 Fold 4 Epoch 280] Train Loss: 0.0436 | Val Loss: 0.0284
# [Rep 3 Fold 4 Epoch 290] Train Loss: 0.0397 | Val Loss: 0.0292
# [Rep 3 Fold 4 Epoch 300] Train Loss: 0.0372 | Val Loss: 0.0279
# [Rep 3 Fold 4 Epoch 310] Train Loss: 0.0393 | Val Loss: 0.0308
# [Rep 3 Fold 4 Epoch 320] Train Loss: 0.0373 | Val Loss: 0.0277
# [Rep 3 Fold 4 Epoch 330] Train Loss: 0.0418 | Val Loss: 0.0287
# [Rep 3 Fold 4 Epoch 340] Train Loss: 0.0383 | Val Loss: 0.0319
# [Rep 3 Fold 4 Epoch 350] Train Loss: 0.0410 | Val Loss: 0.1404
# [Rep 3 Fold 4 Epoch 360] Train Loss: 0.0419 | Val Loss: 0.0316
# [Rep 3 Fold 4 Epoch 370] Train Loss: 0.0388 | Val Loss: 0.0576
# [Rep 3 Fold 4 Epoch 380] Train Loss: 0.0419 | Val Loss: 0.0316
# [Rep 3 Fold 4 Epoch 390] Train Loss: 0.0372 | Val Loss: 0.0310
# [Rep 3 Fold 4 Epoch 400] Train Loss: 0.0379 | Val Loss: 0.0274
# [Rep 3 Fold 4 Epoch 410] Train Loss: 0.0416 | Val Loss: 0.0257
# [Rep 3 Fold 4 Epoch 420] Train Loss: 0.0419 | Val Loss: 0.0333
# [Rep 3 Fold 4 Epoch 430] Train Loss: 0.0437 | Val Loss: 0.0313
# [Rep 3 Fold 4 Epoch 440] Train Loss: 0.0359 | Val Loss: 0.0268
# [Rep 3 Fold 4 Epoch 450] Train Loss: 0.0336 | Val Loss: 0.0267
# [Rep 3 Fold 4 Epoch 460] Train Loss: 0.0342 | Val Loss: 0.0276
# [Rep 3 Fold 4 Epoch 470] Train Loss: 0.0381 | Val Loss: 0.0317
# [Rep 3 Fold 4 Epoch 480] Train Loss: 0.0355 | Val Loss: 0.0291
# [Rep 3 Fold 4 Epoch 490] Train Loss: 0.0393 | Val Loss: 0.0277
# [Rep 3 Fold 4 Epoch 500] Train Loss: 0.0363 | Val Loss: 0.0291
# Evaluating Rep 3 Fold 4 ...
# R²: 0.5179
# RMSE: 0.1707
#
# --- Repetition 3 - Fold 5 ---
# [Rep 3 Fold 5 Epoch 10] Train Loss: 0.1236 | Val Loss: 0.0564
# [Rep 3 Fold 5 Epoch 20] Train Loss: 0.0534 | Val Loss: 0.0568
# [Rep 3 Fold 5 Epoch 30] Train Loss: 0.0658 | Val Loss: 0.1022
# [Rep 3 Fold 5 Epoch 40] Train Loss: 0.0649 | Val Loss: 0.0573
# [Rep 3 Fold 5 Epoch 50] Train Loss: 0.0556 | Val Loss: 0.0595
# [Rep 3 Fold 5 Epoch 60] Train Loss: 0.0700 | Val Loss: 0.0584
# [Rep 3 Fold 5 Epoch 70] Train Loss: 0.0450 | Val Loss: 0.0536
# [Rep 3 Fold 5 Epoch 80] Train Loss: 0.0499 | Val Loss: 0.0556
# [Rep 3 Fold 5 Epoch 90] Train Loss: 0.0480 | Val Loss: 0.0503
# [Rep 3 Fold 5 Epoch 100] Train Loss: 0.0540 | Val Loss: 0.0571
# [Rep 3 Fold 5 Epoch 110] Train Loss: 0.0449 | Val Loss: 0.0497
# [Rep 3 Fold 5 Epoch 120] Train Loss: 0.0496 | Val Loss: 0.0538
# [Rep 3 Fold 5 Epoch 130] Train Loss: 0.0462 | Val Loss: 0.0436
# [Rep 3 Fold 5 Epoch 140] Train Loss: 0.0520 | Val Loss: 0.0492
# [Rep 3 Fold 5 Epoch 150] Train Loss: 0.0416 | Val Loss: 0.0486
# [Rep 3 Fold 5 Epoch 160] Train Loss: 0.0389 | Val Loss: 0.0466
# [Rep 3 Fold 5 Epoch 170] Train Loss: 0.0416 | Val Loss: 0.0517
# [Rep 3 Fold 5 Epoch 180] Train Loss: 0.0525 | Val Loss: 0.0461
# [Rep 3 Fold 5 Epoch 190] Train Loss: 0.0445 | Val Loss: 0.0402
# [Rep 3 Fold 5 Epoch 200] Train Loss: 0.0507 | Val Loss: 0.0777
# [Rep 3 Fold 5 Epoch 210] Train Loss: 0.0384 | Val Loss: 0.0346
# [Rep 3 Fold 5 Epoch 220] Train Loss: 0.0362 | Val Loss: 0.0385
# [Rep 3 Fold 5 Epoch 230] Train Loss: 0.0438 | Val Loss: 0.0435
# [Rep 3 Fold 5 Epoch 240] Train Loss: 0.0371 | Val Loss: 0.0317
# [Rep 3 Fold 5 Epoch 250] Train Loss: 0.0410 | Val Loss: 0.0375
# [Rep 3 Fold 5 Epoch 260] Train Loss: 0.0358 | Val Loss: 0.0326
# [Rep 3 Fold 5 Epoch 270] Train Loss: 0.0359 | Val Loss: 0.0382
# [Rep 3 Fold 5 Epoch 280] Train Loss: 0.0327 | Val Loss: 0.0320
# [Rep 3 Fold 5 Epoch 290] Train Loss: 0.0282 | Val Loss: 0.0300
# ...
# [Rep 10 Fold 1 Epoch 290] Train Loss: 6.1926 | Val Loss: 0.7684
# [Rep 10 Fold 1 Epoch 300] Train Loss: 0.1509 | Val Loss: 0.2274
# [Rep 10 Fold 1 Epoch 310] Train Loss: 0.1369 | Val Loss: 0.0966
# [Rep 10 Fold 1 Epoch 320] Train Loss: 0.1410 | Val Loss: 0.7181
# [Rep 10 Fold 1 Epoch 330] Train Loss: 0.0712 | Val Loss: 0.0886
# [Rep 10 Fold 1 Epoch 340] Train Loss: 0.0538 | Val Loss: 0.0819
# [Rep 10 Fold 1 Epoch 350] Train Loss: 0.0648 | Val Loss: 0.0902
# [Rep 10 Fold 1 Epoch 360] Train Loss: 0.0865 | Val Loss: 0.0927
# [Rep 10 Fold 1 Epoch 370] Train Loss: 0.0852 | Val Loss: 0.0935
# [Rep 10 Fold 1 Epoch 380] Train Loss: 0.0565 | Val Loss: 0.0728
# [Rep 10 Fold 1 Epoch 390] Train Loss: 0.0398 | Val Loss: 0.1157
# [Rep 10 Fold 1 Epoch 400] Train Loss: 0.0700 | Val Loss: 0.0730
# [Rep 10 Fold 1 Epoch 410] Train Loss: 0.0600 | Val Loss: 0.0705
# [Rep 10 Fold 1 Epoch 420] Train Loss: 0.0580 | Val Loss: 0.0759
# [Rep 10 Fold 1 Epoch 430] Train Loss: 0.0545 | Val Loss: 0.0778
# [Rep 10 Fold 1 Epoch 440] Train Loss: 0.0504 | Val Loss: 0.0812
# [Rep 10 Fold 1 Epoch 450] Train Loss: 0.0546 | Val Loss: 0.0734
# [Rep 10 Fold 1 Epoch 460] Train Loss: 0.0649 | Val Loss: 0.0783
# [Rep 10 Fold 1 Epoch 470] Train Loss: 0.0714 | Val Loss: 0.0954
# [Rep 10 Fold 1 Epoch 480] Train Loss: 0.0642 | Val Loss: 0.0643
# [Rep 10 Fold 1 Epoch 490] Train Loss: 0.0754 | Val Loss: 0.1553
# [Rep 10 Fold 1 Epoch 500] Train Loss: 0.0841 | Val Loss: 0.1047
# Evaluating Rep 10 Fold 1 ...
# R²: -0.0281
# RMSE: 0.3236
#
# --- Repetition 10 - Fold 2 ---
# [Rep 10 Fold 2 Epoch 10] Train Loss: 0.0679 | Val Loss: 0.0866
# [Rep 10 Fold 2 Epoch 20] Train Loss: 0.1724 | Val Loss: 0.0866
# [Rep 10 Fold 2 Epoch 30] Train Loss: 0.9550 | Val Loss: 0.8712
# [Rep 10 Fold 2 Epoch 40] Train Loss: 0.0740 | Val Loss: 0.0783
# [Rep 10 Fold 2 Epoch 50] Train Loss: 0.0709 | Val Loss: 0.0720
# [Rep 10 Fold 2 Epoch 60] Train Loss: 0.1158 | Val Loss: 0.3221
# [Rep 10 Fold 2 Epoch 70] Train Loss: 0.0594 | Val Loss: 0.0691
# [Rep 10 Fold 2 Epoch 80] Train Loss: 0.1134 | Val Loss: 0.0823
# [Rep 10 Fold 2 Epoch 90] Train Loss: 0.0926 | Val Loss: 0.0996
# [Rep 10 Fold 2 Epoch 100] Train Loss: 0.0792 | Val Loss: 0.1303
# [Rep 10 Fold 2 Epoch 110] Train Loss: 2.4159 | Val Loss: 0.3551
# [Rep 10 Fold 2 Epoch 120] Train Loss: 0.0707 | Val Loss: 0.0604
# [Rep 10 Fold 2 Epoch 130] Train Loss: 0.0582 | Val Loss: 0.1547
# [Rep 10 Fold 2 Epoch 140] Train Loss: 0.0854 | Val Loss: 0.0774
# [Rep 10 Fold 2 Epoch 150] Train Loss: 0.0484 | Val Loss: 0.0668
# [Rep 10 Fold 2 Epoch 160] Train Loss: 0.0533 | Val Loss: 0.0869
# [Rep 10 Fold 2 Epoch 170] Train Loss: 0.0539 | Val Loss: 0.0780
# [Rep 10 Fold 2 Epoch 180] Train Loss: 0.0561 | Val Loss: 0.1446
# [Rep 10 Fold 2 Epoch 190] Train Loss: 0.0585 | Val Loss: 0.1130
# [Rep 10 Fold 2 Epoch 200] Train Loss: 0.0554 | Val Loss: 0.0646
# [Rep 10 Fold 2 Epoch 210] Train Loss: 0.0544 | Val Loss: 0.1341
# [Rep 10 Fold 2 Epoch 220] Train Loss: 0.0717 | Val Loss: 0.2936
# [Rep 10 Fold 2 Epoch 230] Train Loss: 0.0664 | Val Loss: 0.0632
# [Rep 10 Fold 2 Epoch 240] Train Loss: 0.0619 | Val Loss: 0.0696
# [Rep 10 Fold 2 Epoch 250] Train Loss: 0.0484 | Val Loss: 0.1239
# [Rep 10 Fold 2 Epoch 260] Train Loss: 0.1027 | Val Loss: 0.0859
# [Rep 10 Fold 2 Epoch 270] Train Loss: 0.0630 | Val Loss: 0.0936
# [Rep 10 Fold 2 Epoch 280] Train Loss: 0.0570 | Val Loss: 0.1016
# [Rep 10 Fold 2 Epoch 290] Train Loss: 0.0551 | Val Loss: 0.1589
# [Rep 10 Fold 2 Epoch 300] Train Loss: 0.8261 | Val Loss: 0.2723
# [Rep 10 Fold 2 Epoch 310] Train Loss: 0.0814 | Val Loss: 0.1593
# [Rep 10 Fold 2 Epoch 320] Train Loss: 0.0596 | Val Loss: 0.2086
# [Rep 10 Fold 2 Epoch 330] Train Loss: 0.0690 | Val Loss: 0.0926
# [Rep 10 Fold 2 Epoch 340] Train Loss: 0.0396 | Val Loss: 0.1603
# [Rep 10 Fold 2 Epoch 350] Train Loss: 0.1148 | Val Loss: 0.1346
# [Rep 10 Fold 2 Epoch 360] Train Loss: 0.0520 | Val Loss: 0.1758
# [Rep 10 Fold 2 Epoch 370] Train Loss: 0.0714 | Val Loss: 0.1186
# [Rep 10 Fold 2 Epoch 380] Train Loss: 0.0622 | Val Loss: 0.0761
# [Rep 10 Fold 2 Epoch 390] Train Loss: 0.0583 | Val Loss: 0.1147
# [Rep 10 Fold 2 Epoch 400] Train Loss: 0.0527 | Val Loss: 0.1397
# [Rep 10 Fold 2 Epoch 410] Train Loss: 0.0481 | Val Loss: 0.0716
# [Rep 10 Fold 2 Epoch 420] Train Loss: 0.0488 | Val Loss: 0.0983
# [Rep 10 Fold 2 Epoch 430] Train Loss: 0.0702 | Val Loss: 0.1291
# [Rep 10 Fold 2 Epoch 440] Train Loss: 0.0547 | Val Loss: 0.0764
# [Rep 10 Fold 2 Epoch 450] Train Loss: 0.0376 | Val Loss: 0.1231
# [Rep 10 Fold 2 Epoch 460] Train Loss: 0.0413 | Val Loss: 0.0799
# [Rep 10 Fold 2 Epoch 470] Train Loss: 0.0358 | Val Loss: 0.0685
# [Rep 10 Fold 2 Epoch 480] Train Loss: 0.0507 | Val Loss: 0.0763
# [Rep 10 Fold 2 Epoch 490] Train Loss: 0.0555 | Val Loss: 0.0900
# [Rep 10 Fold 2 Epoch 500] Train Loss: 0.0385 | Val Loss: 0.0803
# Evaluating Rep 10 Fold 2 ...
# R²: 0.2350
# RMSE: 0.2834
#
# --- Repetition 10 - Fold 3 ---
# [Rep 10 Fold 3 Epoch 10] Train Loss: 0.5792 | Val Loss: 0.6185
# [Rep 10 Fold 3 Epoch 20] Train Loss: 0.1073 | Val Loss: 0.0740
# [Rep 10 Fold 3 Epoch 30] Train Loss: 0.2158 | Val Loss: 0.2398
# [Rep 10 Fold 3 Epoch 40] Train Loss: 0.7983 | Val Loss: 1.1889
# [Rep 10 Fold 3 Epoch 50] Train Loss: 0.0729 | Val Loss: 0.0862
# [Rep 10 Fold 3 Epoch 60] Train Loss: 0.5413 | Val Loss: 0.8214
# [Rep 10 Fold 3 Epoch 70] Train Loss: 0.0693 | Val Loss: 0.1258
# [Rep 10 Fold 3 Epoch 80] Train Loss: 0.0741 | Val Loss: 0.0727
# [Rep 10 Fold 3 Epoch 90] Train Loss: 0.0640 | Val Loss: 0.1143
# [Rep 10 Fold 3 Epoch 100] Train Loss: 0.0674 | Val Loss: 0.0831
# [Rep 10 Fold 3 Epoch 110] Train Loss: 0.1995 | Val Loss: 0.0812
# [Rep 10 Fold 3 Epoch 120] Train Loss: 0.0845 | Val Loss: 0.0759
# [Rep 10 Fold 3 Epoch 130] Train Loss: 0.1545 | Val Loss: 0.1026
# [Rep 10 Fold 3 Epoch 140] Train Loss: 0.0637 | Val Loss: 0.0707
# [Rep 10 Fold 3 Epoch 150] Train Loss: 0.0625 | Val Loss: 0.0761
# [Rep 10 Fold 3 Epoch 160] Train Loss: 0.0619 | Val Loss: 0.0673
# [Rep 10 Fold 3 Epoch 170] Train Loss: 0.2250 | Val Loss: 0.1464
# [Rep 10 Fold 3 Epoch 180] Train Loss: 0.0686 | Val Loss: 0.0898
# [Rep 10 Fold 3 Epoch 190] Train Loss: 0.0716 | Val Loss: 0.0679
# [Rep 10 Fold 3 Epoch 200] Train Loss: 0.0472 | Val Loss: 0.0737
# [Rep 10 Fold 3 Epoch 210] Train Loss: 0.0857 | Val Loss: 0.2183
# [Rep 10 Fold 3 Epoch 220] Train Loss: 0.0639 | Val Loss: 0.0716
# [Rep 10 Fold 3 Epoch 230] Train Loss: 0.0539 | Val Loss: 0.0716
# [Rep 10 Fold 3 Epoch 240] Train Loss: 0.0653 | Val Loss: 0.0812
# [Rep 10 Fold 3 Epoch 250] Train Loss: 0.0721 | Val Loss: 0.0744
# [Rep 10 Fold 3 Epoch 260] Train Loss: 0.0578 | Val Loss: 0.0668
# [Rep 10 Fold 3 Epoch 270] Train Loss: 0.0686 | Val Loss: 0.0603
# [Rep 10 Fold 3 Epoch 280] Train Loss: 0.0653 | Val Loss: 0.1277
# [Rep 10 Fold 3 Epoch 290] Train Loss: 0.0594 | Val Loss: 0.0670
# [Rep 10 Fold 3 Epoch 300] Train Loss: 0.0702 | Val Loss: 0.0846
# [Rep 10 Fold 3 Epoch 310] Train Loss: 0.1162 | Val Loss: 0.0979
# [Rep 10 Fold 3 Epoch 320] Train Loss: 0.6079 | Val Loss: 0.0996
# [Rep 10 Fold 3 Epoch 330] Train Loss: 0.2251 | Val Loss: 0.3626
# [Rep 10 Fold 3 Epoch 340] Train Loss: 0.0842 | Val Loss: 0.1617
# [Rep 10 Fold 3 Epoch 350] Train Loss: 0.0866 | Val Loss: 0.2550
# [Rep 10 Fold 3 Epoch 360] Train Loss: 0.1263 | Val Loss: 0.0795
# [Rep 10 Fold 3 Epoch 370] Train Loss: 0.0455 | Val Loss: 0.1264
# [Rep 10 Fold 3 Epoch 380] Train Loss: 0.0927 | Val Loss: 0.0855
# [Rep 10 Fold 3 Epoch 390] Train Loss: 0.0743 | Val Loss: 0.0703
# [Rep 10 Fold 3 Epoch 400] Train Loss: 0.0692 | Val Loss: 0.0699
# [Rep 10 Fold 3 Epoch 410] Train Loss: 0.0847 | Val Loss: 0.1235
# [Rep 10 Fold 3 Epoch 420] Train Loss: 0.0472 | Val Loss: 0.0774
# [Rep 10 Fold 3 Epoch 430] Train Loss: 0.0693 | Val Loss: 0.0672
# [Rep 10 Fold 3 Epoch 440] Train Loss: 0.0825 | Val Loss: 0.1217
# [Rep 10 Fold 3 Epoch 450] Train Loss: 0.0554 | Val Loss: 0.0749
# [Rep 10 Fold 3 Epoch 460] Train Loss: 0.0957 | Val Loss: 0.0671
# [Rep 10 Fold 3 Epoch 470] Train Loss: 0.0551 | Val Loss: 0.0668
# [Rep 10 Fold 3 Epoch 480] Train Loss: 0.0755 | Val Loss: 0.1120
# [Rep 10 Fold 3 Epoch 490] Train Loss: 0.0506 | Val Loss: 0.1111
# [Rep 10 Fold 3 Epoch 500] Train Loss: 0.0476 | Val Loss: 0.0656
# Evaluating Rep 10 Fold 3 ...
# R²: 0.2256
# RMSE: 0.2560
#
# --- Repetition 10 - Fold 4 ---
# [Rep 10 Fold 4 Epoch 10] Train Loss: 0.0647 | Val Loss: 0.1027
# [Rep 10 Fold 4 Epoch 20] Train Loss: 0.2614 | Val Loss: 0.7554
# [Rep 10 Fold 4 Epoch 30] Train Loss: 0.0724 | Val Loss: 0.1026
# [Rep 10 Fold 4 Epoch 40] Train Loss: 0.1345 | Val Loss: 0.1035
# [Rep 10 Fold 4 Epoch 50] Train Loss: 0.0838 | Val Loss: 0.0625
# [Rep 10 Fold 4 Epoch 60] Train Loss: 7.3748 | Val Loss: 5.7583
# [Rep 10 Fold 4 Epoch 70] Train Loss: 0.1376 | Val Loss: 0.2061
# [Rep 10 Fold 4 Epoch 80] Train Loss: 0.0996 | Val Loss: 0.0636
# [Rep 10 Fold 4 Epoch 90] Train Loss: 0.0433 | Val Loss: 0.0681
# [Rep 10 Fold 4 Epoch 100] Train Loss: 0.1343 | Val Loss: 0.2377
# [Rep 10 Fold 4 Epoch 110] Train Loss: 0.0505 | Val Loss: 0.0843
# [Rep 10 Fold 4 Epoch 120] Train Loss: 0.1335 | Val Loss: 0.0734
# [Rep 10 Fold 4 Epoch 130] Train Loss: 0.0872 | Val Loss: 0.1609
# [Rep 10 Fold 4 Epoch 140] Train Loss: 0.0775 | Val Loss: 0.1082
# [Rep 10 Fold 4 Epoch 150] Train Loss: 0.0529 | Val Loss: 0.0637
# [Rep 10 Fold 4 Epoch 160] Train Loss: 0.0598 | Val Loss: 0.1104
# [Rep 10 Fold 4 Epoch 170] Train Loss: 0.0497 | Val Loss: 0.0934
# [Rep 10 Fold 4 Epoch 180] Train Loss: 0.0668 | Val Loss: 0.0629
# [Rep 10 Fold 4 Epoch 190] Train Loss: 0.0638 | Val Loss: 0.0916
# [Rep 10 Fold 4 Epoch 200] Train Loss: 0.0723 | Val Loss: 0.0574
# [Rep 10 Fold 4 Epoch 210] Train Loss: 0.0631 | Val Loss: 0.0955
# [Rep 10 Fold 4 Epoch 220] Train Loss: 0.0618 | Val Loss: 0.0840
# [Rep 10 Fold 4 Epoch 230] Train Loss: 0.0943 | Val Loss: 0.1048
# [Rep 10 Fold 4 Epoch 240] Train Loss: 0.0667 | Val Loss: 0.1056
# [Rep 10 Fold 4 Epoch 250] Train Loss: 0.0532 | Val Loss: 0.1593
# [Rep 10 Fold 4 Epoch 260] Train Loss: 0.0487 | Val Loss: 0.0671
# [Rep 10 Fold 4 Epoch 270] Train Loss: 0.0496 | Val Loss: 0.2121
# [Rep 10 Fold 4 Epoch 280] Train Loss: 0.0599 | Val Loss: 0.2892
# [Rep 10 Fold 4 Epoch 290] Train Loss: 0.1214 | Val Loss: 0.1113
# [Rep 10 Fold 4 Epoch 300] Train Loss: 0.0687 | Val Loss: 0.0598
# [Rep 10 Fold 4 Epoch 310] Train Loss: 0.0596 | Val Loss: 0.0545
# [Rep 10 Fold 4 Epoch 320] Train Loss: 0.0798 | Val Loss: 0.0704
# [Rep 10 Fold 4 Epoch 330] Train Loss: 0.0594 | Val Loss: 0.0611
# [Rep 10 Fold 4 Epoch 340] Train Loss: 0.0625 | Val Loss: 0.0577
# [Rep 10 Fold 4 Epoch 350] Train Loss: 0.0856 | Val Loss: 0.1270
# [Rep 10 Fold 4 Epoch 360] Train Loss: 0.0697 | Val Loss: 0.0846
# [Rep 10 Fold 4 Epoch 370] Train Loss: 0.0635 | Val Loss: 0.0701
# [Rep 10 Fold 4 Epoch 380] Train Loss: 0.0644 | Val Loss: 0.0668
# [Rep 10 Fold 4 Epoch 390] Train Loss: 5.8747 | Val Loss: 0.4855
# [Rep 10 Fold 4 Epoch 400] Train Loss: 0.0938 | Val Loss: 0.1515
# [Rep 10 Fold 4 Epoch 410] Train Loss: 0.0553 | Val Loss: 0.1153
# [Rep 10 Fold 4 Epoch 420] Train Loss: 0.0610 | Val Loss: 0.0681
# [Rep 10 Fold 4 Epoch 430] Train Loss: 0.0788 | Val Loss: 0.0665
# [Rep 10 Fold 4 Epoch 440] Train Loss: 0.0712 | Val Loss: 0.0845
# [Rep 10 Fold 4 Epoch 450] Train Loss: 0.0750 | Val Loss: 0.1086
# [Rep 10 Fold 4 Epoch 460] Train Loss: 0.0528 | Val Loss: 0.0668
# [Rep 10 Fold 4 Epoch 470] Train Loss: 0.0802 | Val Loss: 0.0922
# [Rep 10 Fold 4 Epoch 480] Train Loss: 0.0528 | Val Loss: 0.0739
# [Rep 10 Fold 4 Epoch 490] Train Loss: 0.0539 | Val Loss: 0.0666
# [Rep 10 Fold 4 Epoch 500] Train Loss: 0.0585 | Val Loss: 0.0751
# Evaluating Rep 10 Fold 4 ...
# R²: 0.2086
# RMSE: 0.2741
#
# --- Repetition 10 - Fold 5 ---
# [Rep 10 Fold 5 Epoch 10] Train Loss: 0.0676 | Val Loss: 0.1801
# [Rep 10 Fold 5 Epoch 20] Train Loss: 0.0786 | Val Loss: 0.2102
# [Rep 10 Fold 5 Epoch 30] Train Loss: 0.0536 | Val Loss: 0.1254
# [Rep 10 Fold 5 Epoch 40] Train Loss: 0.0576 | Val Loss: 0.1277
# [Rep 10 Fold 5 Epoch 50] Train Loss: 0.1509 | Val Loss: 0.1259
# [Rep 10 Fold 5 Epoch 60] Train Loss: 0.0698 | Val Loss: 0.1324
# [Rep 10 Fold 5 Epoch 70] Train Loss: 0.0848 | Val Loss: 0.1277
# [Rep 10 Fold 5 Epoch 80] Train Loss: 0.0507 | Val Loss: 0.1266
# [Rep 10 Fold 5 Epoch 90] Train Loss: 0.1386 | Val Loss: 0.1350
# [Rep 10 Fold 5 Epoch 100] Train Loss: 0.1041 | Val Loss: 0.1144
# [Rep 10 Fold 5 Epoch 110] Train Loss: 0.1494 | Val Loss: 0.3348
# [Rep 10 Fold 5 Epoch 120] Train Loss: 0.3185 | Val Loss: 0.1054
# [Rep 10 Fold 5 Epoch 130] Train Loss: 0.0864 | Val Loss: 0.1045
# [Rep 10 Fold 5 Epoch 140] Train Loss: 0.2770 | Val Loss: 0.2080
# [Rep 10 Fold 5 Epoch 150] Train Loss: 0.0765 | Val Loss: 0.2810
# [Rep 10 Fold 5 Epoch 160] Train Loss: 0.3131 | Val Loss: 0.2866
# [Rep 10 Fold 5 Epoch 170] Train Loss: 0.0682 | Val Loss: 0.1038
# [Rep 10 Fold 5 Epoch 180] Train Loss: 0.0724 | Val Loss: 0.1063
# [Rep 10 Fold 5 Epoch 190] Train Loss: 0.4787 | Val Loss: 0.4962
# [Rep 10 Fold 5 Epoch 200] Train Loss: 0.0445 | Val Loss: 0.1902
# [Rep 10 Fold 5 Epoch 210] Train Loss: 0.0803 | Val Loss: 0.1385
# [Rep 10 Fold 5 Epoch 220] Train Loss: 0.0851 | Val Loss: 0.1267
# [Rep 10 Fold 5 Epoch 230] Train Loss: 0.0532 | Val Loss: 0.1069
# [Rep 10 Fold 5 Epoch 240] Train Loss: 0.0473 | Val Loss: 0.1105
# [Rep 10 Fold 5 Epoch 250] Train Loss: 0.0664 | Val Loss: 0.1107
# [Rep 10 Fold 5 Epoch 260] Train Loss: 0.0572 | Val Loss: 0.1052
# [Rep 10 Fold 5 Epoch 270] Train Loss: 0.0400 | Val Loss: 0.1206
# [Rep 10 Fold 5 Epoch 280] Train Loss: 0.1257 | Val Loss: 0.2444
# [Rep 10 Fold 5 Epoch 290] Train Loss: 0.0438 | Val Loss: 0.1311
# [Rep 10 Fold 5 Epoch 300] Train Loss: 0.0450 | Val Loss: 0.1420
# [Rep 10 Fold 5 Epoch 310] Train Loss: 0.0672 | Val Loss: 0.2393
# [Rep 10 Fold 5 Epoch 320] Train Loss: 0.0686 | Val Loss: 0.2287
# [Rep 10 Fold 5 Epoch 330] Train Loss: 0.0611 | Val Loss: 0.1753
# [Rep 10 Fold 5 Epoch 340] Train Loss: 0.0696 | Val Loss: 0.1101
# [Rep 10 Fold 5 Epoch 350] Train Loss: 1.3068 | Val Loss: 0.3449
# [Rep 10 Fold 5 Epoch 360] Train Loss: 0.0801 | Val Loss: 0.2835
# [Rep 10 Fold 5 Epoch 370] Train Loss: 0.0687 | Val Loss: 0.1567
# [Rep 10 Fold 5 Epoch 380] Train Loss: 0.0526 | Val Loss: 0.1396
# [Rep 10 Fold 5 Epoch 390] Train Loss: 0.0452 | Val Loss: 0.1718
# [Rep 10 Fold 5 Epoch 400] Train Loss: 0.0579 | Val Loss: 0.1766
# [Rep 10 Fold 5 Epoch 410] Train Loss: 0.0583 | Val Loss: 0.1426
# [Rep 10 Fold 5 Epoch 420] Train Loss: 0.0478 | Val Loss: 0.1408
# [Rep 10 Fold 5 Epoch 430] Train Loss: 0.0670 | Val Loss: 0.1579
# [Rep 10 Fold 5 Epoch 440] Train Loss: 0.0690 | Val Loss: 0.1242
# [Rep 10 Fold 5 Epoch 450] Train Loss: 0.0562 | Val Loss: 0.1280
# [Rep 10 Fold 5 Epoch 460] Train Loss: 0.0496 | Val Loss: 0.1313
# [Rep 10 Fold 5 Epoch 470] Train Loss: 0.0535 | Val Loss: 0.1191
# [Rep 10 Fold 5 Epoch 480] Train Loss: 0.0430 | Val Loss: 0.1184
# [Rep 10 Fold 5 Epoch 490] Train Loss: 0.0479 | Val Loss: 0.1894
# [Rep 10 Fold 5 Epoch 500] Train Loss: 0.0528 | Val Loss: 0.1433
# Evaluating Rep 10 Fold 5 ...
# R²: -0.0617
# RMSE: 0.3785
#
# --- Repetition 10 Summary ---
# Mean R²: 0.1159 ± 0.1320
# Mean RMSE: 0.3031 ± 0.0437
#
# --- Grid Search Summary for this configuration ---
# hidden_dim: 200, batch_size: 64, weight_decay: 0
# Overall Mean R²: 0.0514 ± 0.0884
# Overall Mean RMSE: 0.2947 ± 0.0082
#
# ==========================================
# FINAL GRID SEARCH RESULTS
# ==========================================
#
# Configuration: hidden_dim=16, batch_size=16, weight_decay=1e-05
# Overall Mean R²: 0.1459 ± 0.4010
# Overall Mean RMSE: 0.2268 ± 0.0373
#
# Configuration: hidden_dim=16, batch_size=16, weight_decay=0
# Overall Mean R²: 0.3489 ± 0.3437
# Overall Mean RMSE: 0.2057 ± 0.0288
#
# Configuration: hidden_dim=16, batch_size=64, weight_decay=1e-05
# Overall Mean R²: 0.1979 ± 0.1178
# Overall Mean RMSE: 0.2576 ± 0.0178
#
# Configuration: hidden_dim=16, batch_size=64, weight_decay=0
# Overall Mean R²: 0.2523 ± 0.1427
# Overall Mean RMSE: 0.2511 ± 0.0214
#
# Configuration: hidden_dim=200, batch_size=16, weight_decay=1e-05
# Overall Mean R²: 0.3352 ± 0.0945
# Overall Mean RMSE: 0.2204 ± 0.0169
#
# Configuration: hidden_dim=200, batch_size=16, weight_decay=0
# Overall Mean R²: 0.2801 ± 0.1402
# Overall Mean RMSE: 0.2239 ± 0.0205
#
# Configuration: hidden_dim=200, batch_size=64, weight_decay=1e-05
# Overall Mean R²: 0.0964 ± 0.1346
# Overall Mean RMSE: 0.2832 ± 0.0250
#
# Configuration: hidden_dim=200, batch_size=64, weight_decay=0
# Overall Mean R²: 0.0514 ± 0.0884
# Overall Mean RMSE: 0.2947 ± 0.0082

# %% [markdown]
# ----
# ### Optuna part

# %%
# =============================================================================
#             IMPROVED MODEL WITH TRAPEZOID DIMENSIONS & PROJECTIONS
# =============================================================================
import optuna
import optuna.visualization as vis

class GINE_RegressionTrapezoid(nn.Module):
    """
    A GINEConv-based regression model that uses a list of hidden dimensions
    to build layers with decreasing size (trapezoid architecture),
    ensuring dimension consistency with projection layers between convs.
    """
    def __init__(self,
                 node_in_dim: int,
                 edge_in_dim: int,
                 external_in_dim: int,
                 hidden_dims: list,
                 dropout: float = 0.1):
        super().__init__()

        # For the first layer, encode edges to hidden_dims[0], and encode nodes as well
        self.initial_edge_encoder = nn.Linear(edge_in_dim, hidden_dims[0])
        self.initial_node_encoder = nn.Linear(node_in_dim, hidden_dims[0])

        # We'll build each GINEConv to transform dimension: hidden_dims[i] -> hidden_dims[i].
        # After each conv i, if i < len(hidden_dims)-1, we project to hidden_dims[i+1].
        self.convs = nn.ModuleList()
        self.bns = nn.ModuleList()
        self.projections = nn.ModuleList()  # for node features
        self.edge_projections = nn.ModuleList()  # for edge features

        for i in range(len(hidden_dims)):
            net = nn.Sequential(
                nn.Linear(hidden_dims[i], hidden_dims[i]),
                nn.ReLU(),
                nn.Linear(hidden_dims[i], hidden_dims[i])
            )
            conv = GINEConv(nn=net)
            self.convs.append(conv)
            self.bns.append(BatchNorm(hidden_dims[i]))

            if i < len(hidden_dims) - 1:
                self.projections.append(nn.Linear(hidden_dims[i], hidden_dims[i+1]))
                self.edge_projections.append(nn.Linear(hidden_dims[i], hidden_dims[i+1]))
            else:
                self.projections.append(None)
                self.edge_projections.append(None)

        self.dropout_layer = nn.Dropout(p=dropout)

        final_dim = hidden_dims[-1]
        self.externals_mlp = nn.Sequential(
            nn.Linear(external_in_dim, final_dim),
            nn.ReLU(),
            nn.Dropout(p=dropout),
            nn.Linear(final_dim, final_dim)
        )

        self.final_regressor = nn.Sequential(
            nn.Linear(final_dim + final_dim, final_dim),
            nn.ReLU(),
            nn.Dropout(p=dropout),
            nn.Linear(final_dim, 1)
        )

    def forward(self, data):
        x, edge_index, edge_attr, batch = data.x, data.edge_index, data.edge_attr, data.batch

        x = self.initial_node_encoder(x)
        edge_emb = self.initial_edge_encoder(edge_attr)

        for i, (conv, bn) in enumerate(zip(self.convs, self.bns)):
            x = conv(x, edge_index, edge_emb)
            x = bn(x)
            x = F.relu(x)
            x = self.dropout_layer(x)

            if i < len(self.projections) - 1 and self.projections[i] is not None:
                x = self.projections[i](x)
                edge_emb = self.edge_projections[i](edge_emb)

        graph_emb = global_mean_pool(x, batch)
        ext_emb = self.externals_mlp(data.externals)
        combined = torch.cat([graph_emb, ext_emb], dim=-1)
        out = self.final_regressor(combined).squeeze(-1)
        return out


def objective(trial):
    """
    Objective function for Optuna.
    We do k-fold cross validation using a new GNN model with a non-increasing
    (trapezoidal) architecture. The hyperparameters include learning rate, dropout,
    number of layers, and for each layer, a hidden dimension chosen from a fixed
    candidate set so that each subsequent layer's dimension is <= the previous layer's.
    We return the average RMSE (lower = better). R² is stored in user_attrs.
    Intermediate validation losses are reported for early stopping & dashboard visualization.
    """
    # Hyperparameter search space
    lr = trial.suggest_categorical("learning_rate", [1e-3, 3e-3, 1e-4, 3e-4])
    dropout = trial.suggest_categorical("dropout", [0.1, 0.5])
    num_layers = trial.suggest_int("num_layers", 2, 6)  # 层数限制

    # 固定候选集：所有层均使用相同的候选集
    candidate_values = [200, 128, 64, 32, 16]

    # 固定定义6个隐藏层参数
    hd0 = trial.suggest_categorical("NEW_hidden_dim_0", candidate_values)
    hd1 = trial.suggest_categorical("NEW_hidden_dim_1", candidate_values)
    hd2 = trial.suggest_categorical("NEW_hidden_dim_2", candidate_values)
    hd3 = trial.suggest_categorical("NEW_hidden_dim_3", candidate_values)
    hd4 = trial.suggest_categorical("NEW_hidden_dim_4", candidate_values)
    hd5 = trial.suggest_categorical("NEW_hidden_dim_5", candidate_values)
    hidden_dims_all = [hd0, hd1, hd2, hd3, hd4, hd5]

    # 只使用前 num_layers 个隐藏层
    hidden_dims = hidden_dims_all[:num_layers]

    # 检查是否满足非递增（梯形）结构
    for i in range(1, num_layers):
        if hidden_dims[i] > hidden_dims[i-1]:
            raise optuna.TrialPruned()

    # Early stopping 参数 epoch往大了设
    max_epochs = 500 
    patience = 10
    min_delta = 1e-5

    kf_local = KFold(n_splits=5, shuffle=True, random_state=42)
    rmse_scores = []
    r2_scores = []

    for fold_idx, (train_idx, val_idx) in enumerate(kf_local.split(dataset)):
        train_subset = torch.utils.data.Subset(dataset, train_idx)
        val_subset = torch.utils.data.Subset(dataset, val_idx)

        train_loader = PyGDataLoader(train_subset, batch_size=16, shuffle=True)
        val_loader = PyGDataLoader(val_subset, batch_size=16, shuffle=False)

        # 构建使用选定梯形隐藏维度的 GNN 模型
        model = GINE_RegressionTrapezoid(
            node_in_dim=1,
            edge_in_dim=2,
            external_in_dim=4,
            hidden_dims=hidden_dims,
            dropout=dropout
        ).to(device)

        optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)
        criterion = nn.MSELoss()

        best_val_loss = float("inf")
        patience_counter = 0

        for epoch in range(1, max_epochs + 1):
            train_loss = train_one_epoch(model, train_loader, optimizer, criterion, device)
            val_loss = validate(model, val_loader, criterion, device)

            trial.report(val_loss, step=epoch)

            if trial.should_prune():
                raise optuna.TrialPruned()

            if val_loss < (best_val_loss - min_delta):
                best_val_loss = val_loss
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    break

        r2_fold, rmse_fold = evaluate_model(model, val_loader, device)
        rmse_scores.append(rmse_fold)
        r2_scores.append(r2_fold)

    avg_rmse = float(np.mean(rmse_scores))
    avg_r2 = float(np.mean(r2_scores))

    trial.set_user_attr("avg_r2", avg_r2)
    return avg_rmse


# =============================================================================
#                           OPTUNA STUDY & DASHBOARD
# =============================================================================
if __name__ == "__main__":
    # 使用 load_if_exists=False 以确保使用全新 study，避免旧数据冲突
    study = optuna.create_study(
        storage="sqlite:///gnn_mix_op09.sqlite3",
        study_name="GNN-mixed model different layers05",
        direction="minimize",
        load_if_exists=False
    )

    study.optimize(objective, n_trials=19525, show_progress_bar=True)

    print("\n================= Optuna Study Results =================")
    best_trial = study.best_trial
    print(f"Best Trial Value (RMSE): {best_trial.value}")
    print("Best Hyperparameters:")
    for key, val in best_trial.params.items():
        print(f"  {key}: {val}")
    print(f"User Attrs (R², etc.): {best_trial.user_attrs}")

    try:
        fig1 = vis.plot_optimization_history(study)
        fig1.show()
    except Exception as e:
        print(f"Could not generate optimization history plot: {e}")

    try:
        fig2 = vis.plot_param_importances(study)
        fig2.show()
    except Exception as e:
        print(f"Could not generate hyperparameter importance plot: {e}")

    try:
        fig3 = vis.plot_intermediate_values(study)
        fig3.show()
    except Exception as e:
        print(f"Could not generate intermediate values plot: {e}")

    print("\n================= End of Optuna Tuning =================")
